# %%
#!pip3 install -U -r requirements.txt

# %%
from __future__ import print_function


import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter


from six.moves import xrange


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.optim as optim

import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision.utils import make_grid
import math


from six.moves import urllib
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
CIFAR = True
if CIFAR:
  training_data = datasets.CIFAR10(root="data", train=True, download=True,
                                    transform=transforms.Compose([
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5,0.5,0.5), (1.0,1.0,1.0))
                                    ]))
  
  validation_data = datasets.CIFAR10(root="data", train=False, download=True,
                                    transform=transforms.Compose([
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5,0.5,0.5), (1.0,1.0,1.0))
                                    ]))
else:
  training_data = datasets.MNIST(root="data", train=True, download=True,
                                    transform=transforms.Compose([
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5), (1.0))
                                    ]))
  
  validation_data = datasets.MNIST(root="data", train=False, download=True,
                                    transform=transforms.Compose([
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5), (1.0))
                                    ])) 


if CIFAR:
  data_variance = np.var(training_data.data / 255.0)
else:
  data_variance = np.var(training_data.data.numpy() / 255.0)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %%
class VectorQuantizerEMA(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, commitment_cost, decay, epsilon=1e-5):
        super(VectorQuantizerEMA, self).__init__()
        
        self._embedding_dim = embedding_dim
        self._num_embeddings = num_embeddings
        
        self._embedding = nn.Embedding(self._num_embeddings, self._embedding_dim)
        self._embedding.weight.data.uniform_(-1/self._num_embeddings, 1/self._num_embeddings) #self._embedding.weight.data.normal_()
        self._commitment_cost = commitment_cost
        
        self.register_buffer('_ema_cluster_size', torch.zeros(num_embeddings))
        self._ema_w = nn.Parameter(torch.Tensor(num_embeddings, self._embedding_dim))
        self._ema_w.data.normal_()
        
        self._decay = decay
        self._epsilon = epsilon
        self.counter = 1.0
        self.fuz_p = 0.0
        self.encoding_indices = 0.0
        self.fcm = True
        self.vqvae = True


       
    def fill_embeddings(self, encoded_data):
      flat_input = encoded_data.view(-1, self._embedding_dim)
      print(flat_input.shape)
      self._embedding.weight.data = flat_input.data[0:self._num_embeddings]
      #self._embedding.weight.data.uniform_(-1/self._num_embeddings, 1/self._num_embeddings) #self._embedding.weight.data.normal_()

    def forward(self, inputs, number):
        # convert inputs from BCHW -> BHWC
        inputs = inputs.permute(0, 2, 3, 1).contiguous()
        input_shape = inputs.shape
        
       
        # Flatten input
        flat_input = inputs.view(-1, self._embedding_dim)
        
        if self.vqvae:
        # Calculate distances
          #distances = (torch.sum(flat_input**2, dim=1, keepdim=True) 
          #              + torch.sum(self._embedding.weight**2, dim=1)
          #              - 2 * torch.matmul(flat_input, self._embedding.weight.t()))

          distances_w = (torch.sum(flat_input.detach()**2, dim=1, keepdim=True) 
                      + torch.sum(self._embedding.weight**2, dim=1)
                      - 2 * torch.matmul(flat_input.detach(), self._embedding.weight.t()))
        else:

          distances_c = (torch.sum(flat_input**2, dim=1, keepdim=True) 
                      + torch.sum(self._embedding.weight.detach()**2, dim=1)
                      - 2 * torch.matmul(flat_input, self._embedding.weight.t().detach()))

          distances_w = (torch.sum(flat_input.detach()**2, dim=1, keepdim=True) 
                      + torch.sum(self._embedding.weight**2, dim=1)
                      - 2 * torch.matmul(flat_input.detach(), self._embedding.weight.t()))

        #literal distance
        


        # Encoding
        self.encoding_indices = torch.argmin(distances_w, dim=1).unsqueeze(1)
        encoding_indices = self.encoding_indices
          #Multinomial
          #ng_p_batch = self.ng_p.repeat(distances.size(0),1)
          #sorted_p = torch.scatter(distances, 1, inds, ng_p_batch)
          #encoding_indices  = torch.multinomial(sorted_p, 2, replacement=True)

 
        encodings = torch.zeros(encoding_indices.shape[0], self._num_embeddings, device=inputs.device)
        encodings.scatter_(1, encoding_indices, 1)
      
      
        # Quantize and unflatten

        quantized = torch.matmul(encodings, self._embedding.weight).view(input_shape)
        #quantized = torch.matmul(encodings, sorted_weights.T).view(input_shape)
        
        

        #ME
        #ng_normal = 0.0
        #if self.counter > 0.5:

        fuz_distances = distances_w
        #fuz_distances += 0.000001
        #m = m*self.counter + (1-self.counter)*1.01
        fuz = m-1

        fuz_distances = fuz_distances**(-1)
        fuz_distances = fuz_distances**fuz
        fuz_sum = torch.sum(fuz_distances, dim=-1, keepdim=True)
        self.fuz_p = fuz_distances/fuz_sum
        #H = torch.sum(self.fuz_p*torch.log(self.fuz_p),dim=-1)
        #H = torch.sum(H)/self.fuz_p.size(0)
        self.fuz_p = self.fuz_p**m
        
        #self.fuz_p = self.fuz_p#/torch.sum(self.fuz_p, dim=-1, keepdim=True)
        self.fuz_p = self.fuz_p

        #norm = torch.sum(self.fuz_p,dim=-1, keepdim=True).detach()
        #self.fuz_p = self.fuz_p/norm
        fuz_expectation_w = torch.sum(self.fuz_p*distances_w.to(device))/self.fuz_p.size(0)
        #fuz_expectation_c = torch.sum(self.fuz_p_c*distances_c.to(device))/self.fuz_p.size(0)
        

        #END ME
        
        # Loss
        e_latent_loss = F.mse_loss(quantized.detach(), inputs)#/self.fuz_p.size(0)

        #q_latent_loss = F.mse_loss(quantized, inputs.detach())

        #stick = torch.sum(self.fuz_p, dim=-1)
        #stick = torch.mean(self.)
        loss =  exstick * fuz_expectation_w + stick*e_latent_loss  - torch.sum(self.fuz_p)
        
          
        #loss = loss.detach()
        #loss = ng_normal

        #if self.iterations > 6000:
        #  loss = 0.0
        #loss = ng_normal #q_latent_loss #ng_normal 

        # Straight Through Estimator

        #quantized = inputs + (quantized - inputs).detach()
        quantized = inputs + (quantized - inputs).detach()

        
        #quantized = quantized.detach()
        #quantized = inputs + (ng_expectations

        
        #if self.iterations > 6000:
        #  quantized = quantized.detach()
        #quantized = inputs + ng_normal - (inputs).detach()
        ###PERPEXILITY
        avg_probs = torch.mean(encodings, dim=0)
        perplexity = torch.exp(-torch.sum(avg_probs * torch.log(avg_probs + 1e-10)))
        #########perplexity = torch.tensor([1])
        ####END PERPELXITLITY
        
        # convert quantized from BHWC -> BCHW
        #return loss, quantized.permute(0, 3, 1, 2).contiguous(), perplexity, encodings
        return (loss, fuz_expectation_w , self._embedding.weight.detach()), quantized.permute(0, 3, 1, 2).contiguous(), perplexity, 0.0



class Residual(nn.Module):
    def __init__(self, in_channels, num_hiddens, num_residual_hiddens):
        super(Residual, self).__init__()
        self._block = nn.Sequential(
            nn.ReLU(True),
            nn.Conv2d(in_channels=in_channels,
                      out_channels=num_residual_hiddens,
                      kernel_size=3, stride=1, padding=1, bias=False),
            nn.ReLU(True),
            nn.Conv2d(in_channels=num_residual_hiddens,
                      out_channels=num_hiddens,
                      kernel_size=1, stride=1, bias=False)
        )
    
    def forward(self, x):
        return x + self._block(x)


class ResidualStack(nn.Module):
    def __init__(self, in_channels, num_hiddens, num_residual_layers, num_residual_hiddens):
        super(ResidualStack, self).__init__()
        self._num_residual_layers = num_residual_layers
        self._layers = nn.ModuleList([Residual(in_channels, num_hiddens, num_residual_hiddens)
                             for _ in range(self._num_residual_layers)])

    def forward(self, x):
        for i in range(self._num_residual_layers):
            x = self._layers[i](x)
        return F.relu(x)

class Encoder(nn.Module):
    def __init__(self, in_channels, num_hiddens, num_residual_layers, num_residual_hiddens):
        super(Encoder, self).__init__()

        self._conv_1 = nn.Conv2d(in_channels=in_channels,
                                 out_channels=num_hiddens//2,
                                 kernel_size=4,
                                 stride=2, padding=1)
        self._conv_2 = nn.Conv2d(in_channels=num_hiddens//2,
                                 out_channels=num_hiddens,
                                 kernel_size=4,
                                 stride=2, padding=1)
        self._conv_3 = nn.Conv2d(in_channels=num_hiddens,
                                 out_channels=num_hiddens,
                                 kernel_size=3,
                                 stride=1, padding=1)
        self._residual_stack = ResidualStack(in_channels=num_hiddens,
                                             num_hiddens=num_hiddens,
                                             num_residual_layers=num_residual_layers,
                                             num_residual_hiddens=num_residual_hiddens)

    def forward(self, inputs):
        x = self._conv_1(inputs)
        x = F.relu(x)
        
        x = self._conv_2(x)
        x = F.relu(x)
        
        x = self._conv_3(x)
        return self._residual_stack(x)

class Decoder(nn.Module):
    def __init__(self, in_channels, num_hiddens, num_residual_layers, num_residual_hiddens, out_channels=3):
        super(Decoder, self).__init__()
        
        self._conv_1 = nn.Conv2d(in_channels=in_channels,
                                 out_channels=num_hiddens,
                                 kernel_size=3, 
                                 stride=1, padding=1)
        
        self._residual_stack = ResidualStack(in_channels=num_hiddens,
                                             num_hiddens=num_hiddens,
                                             num_residual_layers=num_residual_layers,
                                             num_residual_hiddens=num_residual_hiddens)
        
        #self._residual_stack2 = ResidualStack(in_channels=num_hiddens,
        #                                     num_hiddens=num_hiddens,
        #                                     num_residual_layers=num_residual_layers,
        #                                     num_residual_hiddens=num_residual_hiddens)

        self._conv_trans_1 = nn.ConvTranspose2d(in_channels=num_hiddens, 
                                                out_channels=num_hiddens//2,
                                                kernel_size=4, 
                                                stride=2, padding=1)
        
        self._conv_trans_2 = nn.ConvTranspose2d(in_channels=num_hiddens//2, 
                                                out_channels=out_channels,#CHANNELS
                                                kernel_size=4, 
                                                stride=2, padding=1)

    def forward(self, inputs):
        x = self._conv_1(inputs)
        
        x = self._residual_stack(x)
        #x = self._residual_stack2(x)
        
        x = self._conv_trans_1(x)
        x = F.relu(x)
        
        return self._conv_trans_2(x)

#config
batch_size =  128
num_training_updates = 2*15000
epochs = 20

alpha = 10
penality = False
lamda0 = 4
if CIFAR:
  num_hiddens = 128
  num_residual_hiddens = 32
  num_residual_layers = 2

  embedding_dim = 64
  #num_embeddings = 512
  num_embeddings = 512
else:
  num_hiddens = 128
  num_residual_hiddens = 32
  num_residual_layers = 2

  embedding_dim = 32
  #num_embeddings = 512
  num_embeddings = 2

commitment_cost = 1
decay = 0.99
stick = 500
exstick = 500
m = 2.0
#learning_rate = 3e-4
learning_rate = 1e-3


training_loader = DataLoader(training_data, 
                             batch_size=batch_size, 
                             shuffle=True,
                             pin_memory=True)


validation_loader = DataLoader(validation_data,
                               batch_size=32,
                                shuffle=True,
                               pin_memory=True)



class Model(nn.Module):
    def __init__(self, num_hiddens, num_residual_layers, num_residual_hiddens, 
                 num_embeddings, embedding_dim, commitment_cost, training_data, decay=0,in_channels=3, out_channels=3 ):
        super(Model, self).__init__()
        
        self._encoder = Encoder(in_channels, num_hiddens,
                                num_residual_layers, 
                                num_residual_hiddens)
        self._pre_vq_conv = nn.Conv2d(in_channels=num_hiddens, 
                                      out_channels=embedding_dim,
                                      kernel_size=1, 
                                      stride=1)
        self._a1 = torch.nn.Parameter(torch.randn(1))
        self._a2 = torch.nn.Parameter(torch.randn(1))
        if decay > 0.0:
            self._vq_vae = VectorQuantizerEMA(num_embeddings, embedding_dim, 
                                              commitment_cost, decay)
        else:
            self._vq_vae = VectorQuantizer(num_embeddings, embedding_dim,
                                           commitment_cost)
                        
        self._decoder = Decoder(embedding_dim,
                                num_hiddens, 
                                num_residual_layers, 
                                num_residual_hiddens, out_channels)
        sample = DataLoader(validation_data,
                               batch_size=num_embeddings,
                               shuffle=True,
                               pin_memory=True)
        (sample, _) = next(iter(sample))
        print(sample.shape)
        encode = self._encoder(sample).detach()
        encode = self._pre_vq_conv(encode)
        print(encode.shape)
        self._vq_vae.fill_embeddings(encode)
        

    def forward(self, x, number):
        z = self._encoder(x)
        z = self._pre_vq_conv(z)
        loss, quantized, perplexity, _ = self._vq_vae(z, number)
        x_recon = self._decoder(quantized)
        x_recon_ae = self._decoder(z)
        
        return loss, x_recon, x_recon_ae, perplexity


if CIFAR:
  model = Model(num_hiddens, num_residual_layers, num_residual_hiddens,
                num_embeddings, embedding_dim, 
                commitment_cost, training_data, decay).to(device)
else:
  model = Model(num_hiddens, num_residual_layers, num_residual_hiddens,
                num_embeddings, embedding_dim, 
                commitment_cost, training_data, decay,out_channels=1, in_channels=1).to(device)

optimizer = optim.Adam(model.parameters(), lr=learning_rate, amsgrad=False)
# Out:
# torch.Size([512, 3, 32, 32])
# torch.Size([512, 64, 8, 8])
# torch.Size([32768, 64])

# %%
model.train()
train_res_recon_error = []
train_res_perplexity = []
quantize_error = []
expectation_error = []
Lagrangian = True
num_training_updates = 15100
for i in xrange(num_training_updates):
    (data, _) = next(iter(training_loader))
    epoch = i // 1500  
    data = data.to(device)
    optimizer.zero_grad()

    #if epoch>2 :
    #  num = 1.0
    #else:
    #  mum = -1.0
    num=1
    vq_loss, data_recon, x_recon_ae, perplexity = model(data,num)
    expectation = vq_loss[1]
    W = vq_loss[2]
    vq_loss = vq_loss[0]
    recon_error = F.mse_loss(data_recon, data)/data_variance
    recon_error_ae = F.mse_loss(x_recon_ae, data)# / data_variance
    p = F.sigmoid(model._a1)
    loss = recon_error + vq_loss
  
    loss.backward()

    optimizer.step()
    
    train_res_recon_error.append(recon_error.item())
    train_res_perplexity.append(perplexity.item())
    quantize_error.append(vq_loss.item())
    expectation_error.append(expectation.item())

    period = 100

    if (i+period) % period == 0:
        print('%d epoch' % (epoch+1))
        print('%d iterations' % (i+1))
        print('prob parameter: %.3f' % p)
        print('recon_error: %.3f' % np.mean(train_res_recon_error[-period:]))
        print('perplexity: %.3f' % np.mean(train_res_perplexity[-period:]))
        print('vq_loss: %.3f' % np.mean(quantize_error[-period:]))
        print('expectation: %.3f' % np.mean(expectation_error[-period:]))
        #print('vq_loss: %.3f' % vq_loss)
        #print('q_latent_loss: {}'.format(np.mean(quantize_error[-period:])))
        print('ng_p', torch.sort(model._vq_vae.fuz_p)[0])
        print('ng_p sum', torch.sum(model._vq_vae.fuz_p,dim=-1))
        print('W', W)
        #print('ng_p', model._vq_vae.encoding_indices)
        #print('ng_p', torch.sort(model.[1])
        print()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1805: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 1 epoch
# 1 iterations
# prob parameter: 0.652
# recon_error: 1.244
# perplexity: 1.000
# vq_loss: -17.090
# expectation: 0.001
# ng_p tensor([[2.7649e-07, 2.9112e-07, 2.9914e-07,  ..., 1.0046e-05, 1.0345e-05,
#          1.0610e-05],
#         [2.9774e-07, 3.1352e-07, 3.2258e-07,  ..., 9.9524e-06, 1.0078e-05,
#          1.0420e-05],
#         [2.9938e-07, 3.1531e-07, 3.2471e-07,  ..., 9.9601e-06, 1.0003e-05,
#          1.0337e-05],
#         ...,
#         [2.7625e-07, 2.9097e-07, 2.9892e-07,  ..., 1.0246e-05, 1.0556e-05,
#          1.0926e-05],
#         [2.6555e-07, 2.7974e-07, 2.8733e-07,  ..., 1.0378e-05, 1.0617e-05,
#          1.1004e-05],
#         [2.6135e-07, 2.7506e-07, 2.8288e-07,  ..., 1.0363e-05, 1.0555e-05,
#          1.0944e-05]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.0023, 0.0023, 0.0023,  ..., 0.0023, 0.0023, 0.0023], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.0283, -0.0293, -0.0264,  ..., -0.0232, -0.0248, -0.0240],
#         [ 0.0905,  0.0941,  0.0925,  ...,  0.0906,  0.0922,  0.0895],
#         [ 0.0108,  0.0134,  0.0149,  ...,  0.0149,  0.0100, -0.0011],
#         ...,
#         [ 0.0179,  0.0241,  0.0187,  ...,  0.0315,  0.0298,  0.0346],
#         [-0.0108, -0.0159, -0.0153,  ..., -0.0139, -0.0130, -0.0154],
#         [-0.0268, -0.0292, -0.0293,  ..., -0.0257, -0.0183, -0.0310]],
#        device='cuda:0')
#
# 1 epoch
# 101 iterations
# prob parameter: 0.652
# recon_error: 0.523
# perplexity: 13.161
# vq_loss: -940.987
# expectation: 0.000
# ng_p tensor([[1.5641e-08, 1.6221e-08, 1.6386e-08,  ..., 3.6561e-03, 5.8501e-02,
#          1.0534e-01],
#         [3.0674e-09, 3.1775e-09, 3.2125e-09,  ..., 2.6915e-03, 4.6836e-03,
#          5.1797e-01],
#         [4.4036e-09, 4.5650e-09, 4.6130e-09,  ..., 2.8869e-03, 7.3409e-03,
#          4.4526e-01],
#         ...,
#         [9.5272e-09, 9.8735e-09, 9.9833e-09,  ..., 2.5683e-03, 4.2631e-02,
#          1.9993e-01],
#         [8.3466e-09, 8.6550e-09, 8.7461e-09,  ..., 3.1561e-03, 1.9841e-02,
#          2.7867e-01],
#         [6.6907e-09, 6.9336e-09, 7.0106e-09,  ..., 3.8019e-03, 1.3537e-02,
#          3.4277e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.1714, 0.5261, 0.4564,  ..., 0.2476, 0.3036, 0.3616], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.1594, -0.1588, -0.1543,  ..., -0.1534, -0.1567, -0.1541],
#         [ 0.2288,  0.2359,  0.2323,  ...,  0.2317,  0.2323,  0.2289],
#         [ 0.1300,  0.1397,  0.1244,  ...,  0.1389,  0.1305,  0.1116],
#         ...,
#         [ 0.1404,  0.1544,  0.1374,  ...,  0.1538,  0.1542,  0.1557],
#         [-0.1289, -0.1267, -0.1266,  ..., -0.1226, -0.1317, -0.1229],
#         [-0.1555, -0.1552, -0.1536,  ..., -0.1526, -0.1495, -0.1575]],
#        device='cuda:0')
#
# 1 epoch
# 201 iterations
# prob parameter: 0.652
# recon_error: 0.224
# perplexity: 8.654
# vq_loss: -3762.173
# expectation: 0.000
# ng_p tensor([[4.9920e-10, 5.1314e-10, 5.1744e-10,  ..., 4.1829e-04, 6.3051e-04,
#          8.1792e-01],
#         [1.4746e-09, 1.5156e-09, 1.5285e-09,  ..., 1.5098e-04, 2.0337e-03,
#          7.4265e-01],
#         [1.5192e-09, 1.5619e-09, 1.5747e-09,  ..., 1.4656e-03, 3.3720e-03,
#          6.4863e-01],
#         ...,
#         [6.5239e-09, 6.7059e-09, 6.7619e-09,  ..., 2.6893e-03, 7.9952e-02,
#          2.0609e-01],
#         [2.0500e-09, 2.1075e-09, 2.1244e-09,  ..., 1.0778e-03, 7.7692e-03,
#          5.8102e-01],
#         [4.7584e-09, 4.8913e-09, 4.9314e-09,  ..., 1.9316e-03, 5.0692e-02,
#          3.0145e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8190, 0.7450, 0.6538,  ..., 0.2910, 0.5904, 0.3557], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.2717, -0.2600, -0.2701,  ..., -0.2631, -0.2673, -0.2681],
#         [ 0.3558,  0.3693,  0.3574,  ...,  0.3622,  0.3615,  0.3572],
#         [ 0.2243,  0.2559,  0.2167,  ...,  0.2360,  0.2286,  0.2190],
#         ...,
#         [ 0.2464,  0.2738,  0.2414,  ...,  0.2608,  0.2581,  0.2554],
#         [-0.2303, -0.2122, -0.2315,  ..., -0.2252, -0.2332, -0.2346],
#         [-0.2635, -0.2515, -0.2640,  ..., -0.2568, -0.2580, -0.2639]],
#        device='cuda:0')
#
# 1 epoch
# 301 iterations
# prob parameter: 0.652
# recon_error: 0.210
# perplexity: 8.918
# vq_loss: -4375.049
# expectation: 0.001
# ng_p tensor([[9.4227e-09, 9.6651e-09, 9.7402e-09,  ..., 3.5559e-03, 9.1476e-02,
#          1.3835e-01],
#         [1.2476e-08, 1.2798e-08, 1.2897e-08,  ..., 5.8256e-03, 7.3959e-02,
#          1.2542e-01],
#         [1.3186e-08, 1.3526e-08, 1.3631e-08,  ..., 7.5899e-03, 3.1212e-02,
#          1.9391e-01],
#         ...,
#         [2.3982e-09, 2.4597e-09, 2.4790e-09,  ..., 1.8577e-03, 2.0542e-02,
#          4.6909e-01],
#         [1.9983e-09, 2.0496e-09, 2.0656e-09,  ..., 1.4092e-03, 1.8885e-02,
#          4.9477e-01],
#         [1.1252e-09, 1.1541e-09, 1.1631e-09,  ..., 1.1517e-03, 5.9696e-03,
#          6.4186e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.2379, 0.2100, 0.2370,  ..., 0.4923, 0.5159, 0.6494], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.3371, -0.3187, -0.3389,  ..., -0.3300, -0.3354, -0.3390],
#         [ 0.4388,  0.4555,  0.4379,  ...,  0.4451,  0.4430,  0.4379],
#         [ 0.2844,  0.3285,  0.2744,  ...,  0.2945,  0.2874,  0.2839],
#         ...,
#         [ 0.3150,  0.3490,  0.3075,  ...,  0.3262,  0.3207,  0.3149],
#         [-0.2884, -0.2604, -0.2929,  ..., -0.2875, -0.2947, -0.3041],
#         [-0.3261, -0.3067, -0.3292,  ..., -0.3197, -0.3247, -0.3292]],
#        device='cuda:0')
#
# 1 epoch
# 401 iterations
# prob parameter: 0.652
# recon_error: 0.206
# perplexity: 8.949
# vq_loss: -4194.745
# expectation: 0.001
# ng_p tensor([[2.8529e-09, 2.9223e-09, 2.9443e-09,  ..., 2.2559e-03, 3.1647e-02,
#          3.9897e-01],
#         [1.8981e-09, 1.9444e-09, 1.9589e-09,  ..., 1.6517e-03, 1.9316e-02,
#          4.9138e-01],
#         [1.6945e-09, 1.7358e-09, 1.7487e-09,  ..., 1.5757e-03, 1.4921e-02,
#          5.2643e-01],
#         ...,
#         [1.9739e-09, 2.0220e-09, 2.0372e-09,  ..., 1.7417e-03, 9.2945e-03,
#          5.5930e-01],
#         [1.2210e-09, 1.2508e-09, 1.2602e-09,  ..., 1.3791e-03, 6.7553e-03,
#          6.2196e-01],
#         [3.6417e-10, 3.7306e-10, 3.7584e-10,  ..., 4.6586e-04, 1.6927e-03,
#          7.8563e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.4341, 0.5132, 0.5437,  ..., 0.5711, 0.6306, 0.7879], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.3931, -0.3703, -0.3980,  ..., -0.3886, -0.3967, -0.4026],
#         [ 0.5138,  0.5315,  0.5102,  ...,  0.5188,  0.5143,  0.5087],
#         [ 0.3388,  0.3915,  0.3265,  ...,  0.3458,  0.3378,  0.3402],
#         ...,
#         [ 0.3775,  0.4148,  0.3675,  ...,  0.3839,  0.3746,  0.3662],
#         [-0.3377, -0.3026, -0.3453,  ..., -0.3421, -0.3500, -0.3665],
#         [-0.3795, -0.3551, -0.3850,  ..., -0.3746, -0.3847, -0.3876]],
#        device='cuda:0')
#
# 1 epoch
# 501 iterations
# prob parameter: 0.652
# recon_error: 0.204
# perplexity: 8.694
# vq_loss: -3911.135
# expectation: 0.001
# ng_p tensor([[5.7302e-09, 5.8644e-09, 5.9071e-09,  ..., 5.2365e-03, 2.4276e-02,
#          3.2822e-01],
#         [8.8925e-09, 9.1008e-09, 9.1668e-09,  ..., 5.9229e-03, 4.2877e-02,
#          2.1627e-01],
#         [1.0478e-08, 1.0723e-08, 1.0800e-08,  ..., 4.2113e-03, 9.6559e-02,
#          1.1667e-01],
#         ...,
#         [1.2524e-09, 1.2816e-09, 1.2910e-09,  ..., 1.7436e-03, 2.3728e-03,
#          6.7725e-01],
#         [5.3094e-09, 5.4333e-09, 5.4733e-09,  ..., 2.1580e-03, 7.6731e-02,
#          2.3140e-01],
#         [3.9706e-09, 4.0634e-09, 4.0930e-09,  ..., 2.2312e-03, 5.2992e-02,
#          3.0123e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3598, 0.2686, 0.2229,  ..., 0.6817, 0.3129, 0.3584], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.4439, -0.4193, -0.4515,  ..., -0.4444, -0.4556, -0.4632],
#         [ 0.5869,  0.6036,  0.5812,  ...,  0.5892,  0.5817,  0.5760],
#         [ 0.3927,  0.4509,  0.3787,  ...,  0.3946,  0.3848,  0.3935],
#         ...,
#         [ 0.4393,  0.4770,  0.4273,  ...,  0.4388,  0.4251,  0.4144],
#         [-0.3821, -0.3427, -0.3925,  ..., -0.3944, -0.4033, -0.4262],
#         [-0.4277, -0.4009, -0.4353,  ..., -0.4267, -0.4424, -0.4431]],
#        device='cuda:0')
#
# 1 epoch
# 601 iterations
# prob parameter: 0.652
# recon_error: 0.196
# perplexity: 8.496
# vq_loss: -3913.396
# expectation: 0.002
# ng_p tensor([[1.0416e-09, 1.0653e-09, 1.0729e-09,  ..., 1.3166e-03, 5.8285e-03,
#          6.4409e-01],
#         [4.7347e-09, 4.8421e-09, 4.8768e-09,  ..., 2.5913e-03, 1.1524e-01,
#          1.7973e-01],
#         [2.7254e-09, 2.7872e-09, 2.8072e-09,  ..., 2.9237e-03, 5.6139e-03,
#          5.4628e-01],
#         ...,
#         [1.4429e-09, 1.4752e-09, 1.4859e-09,  ..., 1.2509e-03, 5.7131e-03,
#          6.5922e-01],
#         [5.7886e-09, 5.9179e-09, 5.9608e-09,  ..., 1.8484e-03, 1.2164e-01,
#          2.1349e-01],
#         [3.3705e-09, 3.4459e-09, 3.4709e-09,  ..., 1.9312e-03, 2.9226e-02,
#          4.4885e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.6516, 0.2997, 0.5557,  ..., 0.6664, 0.3375, 0.4804], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.4888, -0.4647, -0.4985,  ..., -0.4965, -0.5102, -0.5193],
#         [ 0.6568,  0.6707,  0.6495,  ...,  0.6545,  0.6444,  0.6385],
#         [ 0.4451,  0.5061,  0.4301,  ...,  0.4397,  0.4284,  0.4430],
#         ...,
#         [ 0.4992,  0.5349,  0.4861,  ...,  0.4898,  0.4719,  0.4590],
#         [-0.4213, -0.3800, -0.4337,  ..., -0.4435, -0.4530, -0.4816],
#         [-0.4704, -0.4433, -0.4795,  ..., -0.4753, -0.4960, -0.4944]],
#        device='cuda:0')
#
# 1 epoch
# 701 iterations
# prob parameter: 0.652
# recon_error: 0.188
# perplexity: 8.380
# vq_loss: -3817.343
# expectation: 0.002
# ng_p tensor([[2.6934e-09, 2.7529e-09, 2.7721e-09,  ..., 2.0829e-03, 2.4944e-02,
#          4.2684e-01],
#         [4.4090e-09, 4.5063e-09, 4.5378e-09,  ..., 2.2169e-03, 1.2948e-01,
#          1.6095e-01],
#         [3.5895e-09, 3.6688e-09, 3.6943e-09,  ..., 2.3204e-03, 6.8306e-02,
#          2.7240e-01],
#         ...,
#         [1.3938e-09, 1.4245e-09, 1.4345e-09,  ..., 1.0458e-03, 1.1239e-02,
#          5.7973e-01],
#         [4.9653e-09, 5.0744e-09, 5.1102e-09,  ..., 2.1972e-03, 1.4146e-01,
#          1.5166e-01],
#         [2.2078e-10, 2.2564e-10, 2.2723e-10,  ..., 4.0231e-04, 4.8293e-04,
#          8.4600e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.4552, 0.2955, 0.3451,  ..., 0.5926, 0.2976, 0.8470], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.5313, -0.5090, -0.5426,  ..., -0.5479, -0.5636, -0.5741],
#         [ 0.7266,  0.7364,  0.7184,  ...,  0.7181,  0.7057,  0.6998],
#         [ 0.4983,  0.5601,  0.4833,  ...,  0.4834,  0.4709,  0.4916],
#         ...,
#         [ 0.5600,  0.5918,  0.5466,  ...,  0.5396,  0.5178,  0.5027],
#         [-0.4582, -0.4166, -0.4722,  ..., -0.4921, -0.5017, -0.5359],
#         [-0.5105, -0.4846, -0.5208,  ..., -0.5232, -0.5483, -0.5445]],
#        device='cuda:0')
#
# 1 epoch
# 801 iterations
# prob parameter: 0.652
# recon_error: 0.182
# perplexity: 8.483
# vq_loss: -3990.244
# expectation: 0.003
# ng_p tensor([[3.4630e-09, 3.5370e-09, 3.5617e-09,  ..., 1.9561e-03, 2.8067e-02,
#          4.5049e-01],
#         [5.1021e-09, 5.2118e-09, 5.2483e-09,  ..., 2.8064e-03, 5.4240e-02,
#          2.8983e-01],
#         [6.6284e-09, 6.7700e-09, 6.8171e-09,  ..., 2.3866e-03, 1.3743e-01,
#          1.7879e-01],
#         ...,
#         [7.8789e-09, 8.0459e-09, 8.1017e-09,  ..., 4.6575e-04, 4.0985e-03,
#          5.7599e-01],
#         [1.0655e-10, 1.0881e-10, 1.0957e-10,  ..., 1.1777e-05, 1.7942e-04,
#          9.3026e-01],
#         [6.0044e-09, 6.1326e-09, 6.1753e-09,  ..., 2.3399e-03, 1.1626e-01,
#          2.1144e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.4809, 0.3488, 0.3193,  ..., 0.5810, 0.9305, 0.3307], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.5694, -0.5505, -0.5816,  ..., -0.5985, -0.6143, -0.6263],
#         [ 0.7948,  0.7989,  0.7866,  ...,  0.7766,  0.7637,  0.7575],
#         [ 0.5518,  0.6119,  0.5382,  ...,  0.5233,  0.5113,  0.5376],
#         ...,
#         [ 0.6204,  0.6461,  0.6081,  ...,  0.5850,  0.5612,  0.5438],
#         [-0.4910, -0.4507, -0.5058,  ..., -0.5404, -0.5479, -0.5876],
#         [-0.5464, -0.5232, -0.5571,  ..., -0.5704, -0.5979, -0.5922]],
#        device='cuda:0')
#
# 1 epoch
# 901 iterations
# prob parameter: 0.652
# recon_error: 0.176
# perplexity: 8.408
# vq_loss: -4238.226
# expectation: 0.003
# ng_p tensor([[6.7152e-10, 6.8581e-10, 6.9057e-10,  ..., 7.5021e-04, 3.0139e-03,
#          7.2618e-01],
#         [2.8397e-11, 2.8998e-11, 2.9198e-11,  ..., 5.0661e-05, 7.6094e-05,
#          9.4598e-01],
#         [1.9724e-11, 2.0144e-11, 2.0284e-11,  ..., 4.1730e-05, 4.6413e-05,
#          9.5205e-01],
#         ...,
#         [2.3633e-08, 2.4132e-08, 2.4298e-08,  ..., 2.0632e-02, 2.0850e-02,
#          1.0603e-01],
#         [2.3546e-08, 2.4043e-08, 2.4208e-08,  ..., 9.2667e-03, 5.2900e-02,
#          8.0344e-02],
#         [1.1249e-08, 1.1488e-08, 1.1567e-08,  ..., 1.3814e-02, 1.9450e-02,
#          2.2241e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.7302, 0.9461, 0.9521,  ..., 0.1548, 0.1511, 0.2596], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.6074, -0.5903, -0.6182,  ..., -0.6495, -0.6632, -0.6771],
#         [ 0.8570,  0.8576,  0.8515,  ...,  0.8297,  0.8182,  0.8116],
#         [ 0.6007,  0.6606,  0.5914,  ...,  0.5590,  0.5495,  0.5809],
#         ...,
#         [ 0.6753,  0.6969,  0.6669,  ...,  0.6256,  0.6019,  0.5822],
#         [-0.5236, -0.4833, -0.5371,  ..., -0.5892, -0.5925, -0.6379],
#         [-0.5823, -0.5603, -0.5910,  ..., -0.6182, -0.6459, -0.6386]],
#        device='cuda:0')
#
# 1 epoch
# 1001 iterations
# prob parameter: 0.652
# recon_error: 0.172
# perplexity: 8.594
# vq_loss: -4662.500
# expectation: 0.002
# ng_p tensor([[2.5817e-09, 2.6360e-09, 2.6540e-09,  ..., 2.3920e-03, 5.0141e-02,
#          3.4047e-01],
#         [1.6293e-09, 1.6638e-09, 1.6753e-09,  ..., 1.6471e-03, 2.1413e-02,
#          4.8530e-01],
#         [8.1226e-11, 8.2939e-11, 8.3510e-11,  ..., 1.6918e-04, 4.7635e-04,
#          8.8428e-01],
#         ...,
#         [6.7198e-11, 6.8610e-11, 6.9079e-11,  ..., 1.8473e-04, 2.4269e-04,
#          9.0152e-01],
#         [9.6488e-10, 9.8517e-10, 9.9192e-10,  ..., 1.1481e-03, 1.0238e-02,
#          6.0866e-01],
#         [3.7159e-09, 3.7543e-09, 3.7545e-09,  ..., 2.1121e-03, 1.4664e-01,
#          1.5357e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3946, 0.5094, 0.8850,  ..., 0.9020, 0.6206, 0.3049], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.6431, -0.6252, -0.6508,  ..., -0.6953, -0.7068, -0.7228],
#         [ 0.9086,  0.9086,  0.9070,  ...,  0.8754,  0.8653,  0.8580],
#         [ 0.6407,  0.7029,  0.6372,  ...,  0.5897,  0.5825,  0.6180],
#         ...,
#         [ 0.7202,  0.7409,  0.7171,  ...,  0.6603,  0.6369,  0.6148],
#         [-0.5546, -0.5116, -0.5649,  ..., -0.6331, -0.6323, -0.6832],
#         [-0.6160, -0.5926, -0.6213,  ..., -0.6610, -0.6887, -0.6803]],
#        device='cuda:0')
#
# 1 epoch
# 1101 iterations
# prob parameter: 0.652
# recon_error: 0.167
# perplexity: 8.682
# vq_loss: -4841.027
# expectation: 0.002
# ng_p tensor([[2.5988e-11, 2.6294e-11, 2.6532e-11,  ..., 7.0043e-05, 1.2608e-04,
#          9.3213e-01],
#         [2.1972e-09, 2.2200e-09, 2.2201e-09,  ..., 2.0637e-03, 5.1116e-02,
#          3.4155e-01],
#         [6.8357e-10, 6.9063e-10, 6.9067e-10,  ..., 9.9448e-04, 7.0250e-03,
#          6.5079e-01],
#         ...,
#         [2.4577e-09, 2.5085e-09, 2.5252e-09,  ..., 1.8973e-03, 1.0414e-01,
#          2.4237e-01],
#         [2.5061e-10, 2.5583e-10, 2.5756e-10,  ..., 5.0593e-04, 2.4224e-03,
#          7.7767e-01],
#         [1.8913e-09, 1.9306e-09, 1.9436e-09,  ..., 2.0917e-03, 5.6386e-02,
#          3.4351e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.9323, 0.3965, 0.6593,  ..., 0.3506, 0.7808, 0.4036], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.6763, -0.6561, -0.6805,  ..., -0.7363, -0.7467, -0.7646],
#         [ 0.9540,  0.9548,  0.9566,  ...,  0.9166,  0.9071,  0.8991],
#         [ 0.6757,  0.7412,  0.6782,  ...,  0.6174,  0.6117,  0.6508],
#         ...,
#         [ 0.7594,  0.7807,  0.7619,  ...,  0.6916,  0.6678,  0.6435],
#         [-0.5835, -0.5365, -0.5902,  ..., -0.6725, -0.6687, -0.7248],
#         [-0.6474, -0.6212, -0.6489,  ..., -0.6994, -0.7279, -0.7186]],
#        device='cuda:0')
#
# 1 epoch
# 1201 iterations
# prob parameter: 0.652
# recon_error: 0.165
# perplexity: 8.794
# vq_loss: -4964.356
# expectation: 0.002
# ng_p tensor([[2.0952e-09, 2.1385e-09, 2.1529e-09,  ..., 2.1305e-03, 1.2399e-01,
#          1.9896e-01],
#         [3.2249e-09, 3.2903e-09, 3.3117e-09,  ..., 2.7528e-03, 1.6338e-01,
#          1.7883e-01],
#         [1.0386e-09, 1.0600e-09, 1.0672e-09,  ..., 1.7770e-03, 2.2795e-02,
#          4.9392e-01],
#         ...,
#         [2.7622e-09, 2.8181e-09, 2.8364e-09,  ..., 1.6306e-03, 5.6947e-02,
#          3.7571e-01],
#         [4.6722e-10, 4.7689e-10, 4.8010e-10,  ..., 1.0533e-03, 5.3161e-03,
#          6.8200e-01],
#         [9.1933e-10, 9.3801e-10, 9.4413e-10,  ..., 1.7069e-03, 9.0687e-03,
#          6.3156e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3277, 0.3456, 0.5195,  ..., 0.4347, 0.6888, 0.6426], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.7069, -0.6838, -0.7076,  ..., -0.7735, -0.7836, -0.8033],
#         [ 0.9950,  0.9973,  1.0016,  ...,  0.9544,  0.9448,  0.9363],
#         [ 0.7073,  0.7766,  0.7156,  ...,  0.6428,  0.6378,  0.6803],
#         ...,
#         [ 0.7949,  0.8173,  0.8026,  ...,  0.7203,  0.6955,  0.6693],
#         [-0.6101, -0.5587, -0.6133,  ..., -0.7082, -0.7024, -0.7632],
#         [-0.6763, -0.6469, -0.6740,  ..., -0.7342, -0.7642, -0.7540]],
#        device='cuda:0')
#
# 1 epoch
# 1301 iterations
# prob parameter: 0.652
# recon_error: 0.163
# perplexity: 8.816
# vq_loss: -5063.991
# expectation: 0.002
# ng_p tensor([[2.5042e-10, 2.5548e-10, 2.5713e-10,  ..., 6.2997e-04, 3.7444e-03,
#          7.5534e-01],
#         [1.6654e-09, 1.6991e-09, 1.7101e-09,  ..., 2.0486e-03, 1.0446e-01,
#          2.5155e-01],
#         [1.2192e-09, 1.2439e-09, 1.2520e-09,  ..., 2.2273e-03, 4.2952e-02,
#          4.0549e-01],
#         ...,
#         [3.0492e-12, 3.1117e-12, 3.1325e-12,  ..., 1.7047e-05, 1.9453e-05,
#          9.7158e-01],
#         [1.7436e-09, 1.7441e-09, 1.7620e-09,  ..., 1.9991e-03, 9.8817e-02,
#          2.4288e-01],
#         [1.5702e-10, 1.5862e-10, 1.5863e-10,  ..., 4.8951e-04, 1.5290e-03,
#          8.0622e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.7599, 0.3602, 0.4519,  ..., 0.9716, 0.3461, 0.8084], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.7350, -0.7089, -0.7325,  ..., -0.8074, -0.8178, -0.8390],
#         [ 1.0327,  1.0367,  1.0429,  ...,  0.9895,  0.9793,  0.9703],
#         [ 0.7362,  0.8094,  0.7499,  ...,  0.6663,  0.6616,  0.7071],
#         ...,
#         [ 0.8274,  0.8512,  0.8400,  ...,  0.7468,  0.7206,  0.6928],
#         [-0.6346, -0.5788, -0.6345,  ..., -0.7407, -0.7336, -0.7987],
#         [-0.7029, -0.6701, -0.6972,  ..., -0.7659, -0.7978, -0.7868]],
#        device='cuda:0')
#
# 1 epoch
# 1401 iterations
# prob parameter: 0.652
# recon_error: 0.160
# perplexity: 8.927
# vq_loss: -5125.580
# expectation: 0.002
# ng_p tensor([[1.0533e-10, 1.0747e-10, 1.0817e-10,  ..., 4.3241e-04, 1.6172e-03,
#          8.1405e-01],
#         [6.4419e-10, 6.5704e-10, 6.6122e-10,  ..., 1.9392e-03, 1.3667e-02,
#          6.0147e-01],
#         [1.4109e-11, 1.4395e-11, 1.4489e-11,  ..., 8.1744e-05, 1.4127e-04,
#          9.3268e-01],
#         ...,
#         [2.6996e-10, 2.7267e-10, 2.7269e-10,  ..., 7.0375e-04, 3.9152e-03,
#          7.2921e-01],
#         [1.0847e-12, 1.0956e-12, 1.0957e-12,  ..., 5.9773e-06, 6.2016e-06,
#          9.8319e-01],
#         [1.5752e-09, 1.5909e-09, 1.5910e-09,  ..., 2.2290e-03, 7.5098e-02,
#          2.9249e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8162, 0.6174, 0.9329,  ..., 0.7341, 0.9832, 0.3719], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.7614, -0.7321, -0.7561,  ..., -0.8390, -0.8501, -0.8728],
#         [ 1.0681,  1.0740,  1.0815,  ...,  1.0225,  1.0115,  1.0021],
#         [ 0.7634,  0.8404,  0.7820,  ...,  0.6885,  0.6836,  0.7321],
#         ...,
#         [ 0.8580,  0.8834,  0.8750,  ...,  0.7719,  0.7441,  0.7145],
#         [-0.6575, -0.5972, -0.6545,  ..., -0.7709, -0.7631, -0.8321],
#         [-0.7279, -0.6915, -0.7190,  ..., -0.7954, -0.8296, -0.8177]],
#        device='cuda:0')
#
# 2 epoch
# 1501 iterations
# prob parameter: 0.652
# recon_error: 0.159
# perplexity: 8.919
# vq_loss: -5173.794
# expectation: 0.002
# ng_p tensor([[3.4481e-10, 3.4828e-10, 3.4830e-10,  ..., 1.1875e-03, 7.0734e-03,
#          6.5889e-01],
#         [1.7942e-10, 1.8304e-10, 1.8424e-10,  ..., 7.8683e-04, 3.5596e-03,
#          7.4213e-01],
#         [5.8252e-10, 5.8835e-10, 5.8839e-10,  ..., 1.8525e-03, 1.1130e-02,
#          5.8037e-01],
#         ...,
#         [1.7586e-11, 1.7935e-11, 1.8049e-11,  ..., 1.2281e-04, 1.5518e-04,
#          9.3035e-01],
#         [7.6038e-11, 7.7533e-11, 7.8018e-11,  ..., 2.9514e-05, 3.0356e-04,
#          9.1957e-01],
#         [1.2159e-09, 1.2399e-09, 1.2477e-09,  ..., 1.4348e-03, 4.8174e-02,
#          4.3782e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.6676, 0.7467, 0.5942,  ..., 0.9306, 0.9199, 0.4878], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.7859, -0.7537, -0.7782,  ..., -0.8683, -0.8802, -0.9043],
#         [ 1.1014,  1.1090,  1.1176,  ...,  1.0537,  1.0416,  1.0318],
#         [ 0.7890,  0.8694,  0.8120,  ...,  0.7094,  0.7042,  0.7555],
#         ...,
#         [ 0.8867,  0.9135,  0.9077,  ...,  0.7955,  0.7659,  0.7348],
#         [-0.6787, -0.6144, -0.6733,  ..., -0.7989, -0.7907, -0.8633],
#         [-0.7510, -0.7114, -0.7394,  ..., -0.8227, -0.8592, -0.8466]],
#        device='cuda:0')
#
# 2 epoch
# 1601 iterations
# prob parameter: 0.652
# recon_error: 0.158
# perplexity: 8.974
# vq_loss: -5186.325
# expectation: 0.002
# ng_p tensor([[1.2572e-11, 1.2696e-11, 1.2697e-11,  ..., 8.6105e-05, 1.0318e-04,
#          9.3789e-01],
#         [1.1140e-09, 1.1250e-09, 1.1251e-09,  ..., 2.7898e-03, 3.8120e-02,
#          4.0684e-01],
#         [1.7993e-10, 1.8171e-10, 1.8173e-10,  ..., 5.9035e-04, 3.6631e-03,
#          7.5176e-01],
#         ...,
#         [6.1038e-10, 6.2260e-10, 6.2662e-10,  ..., 2.0224e-03, 2.7647e-02,
#          4.7355e-01],
#         [1.1870e-11, 1.2102e-11, 1.2177e-11,  ..., 5.7674e-06, 6.8891e-05,
#          9.6401e-01],
#         [3.8242e-11, 3.8997e-11, 3.9242e-11,  ..., 2.1090e-04, 5.9219e-04,
#          8.8710e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.9381, 0.4492, 0.7563,  ..., 0.5044, 0.9641, 0.8879], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.8092, -0.7743, -0.7994,  ..., -0.8962, -0.9092, -0.9345],
#         [ 1.1335,  1.1428,  1.1522,  ...,  1.0837,  1.0706,  1.0603],
#         [ 0.8137,  0.8975,  0.8407,  ...,  0.7296,  0.7239,  0.7778],
#         ...,
#         [ 0.9144,  0.9427,  0.9391,  ...,  0.8182,  0.7868,  0.7543],
#         [-0.6990, -0.6307, -0.6913,  ..., -0.8256, -0.8171, -0.8933],
#         [-0.7730, -0.7303, -0.7591,  ..., -0.8488, -0.8876, -0.8743]],
#        device='cuda:0')
#
# 2 epoch
# 1701 iterations
# prob parameter: 0.652
# recon_error: 0.158
# perplexity: 8.934
# vq_loss: -5213.848
# expectation: 0.002
# ng_p tensor([[8.6965e-10, 8.8699e-10, 8.9270e-10,  ..., 2.1741e-03, 9.2112e-02,
#          2.7445e-01],
#         [4.1416e-11, 4.2240e-11, 4.2511e-11,  ..., 2.3126e-04, 8.5612e-04,
#          8.6473e-01],
#         [9.0163e-10, 9.1961e-10, 9.2553e-10,  ..., 2.1925e-03, 1.0091e-01,
#          2.5693e-01],
#         ...,
#         [8.4988e-10, 8.6681e-10, 8.7238e-10,  ..., 2.0332e-03, 8.3967e-02,
#          2.9169e-01],
#         [1.0203e-10, 1.0406e-10, 1.0472e-10,  ..., 5.7535e-04, 2.1155e-03,
#          7.9278e-01],
#         [4.5594e-11, 4.6501e-11, 4.6799e-11,  ..., 2.5715e-04, 9.2513e-04,
#          8.5869e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3707, 0.8659, 0.3621,  ..., 0.3797, 0.7956, 0.8599], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.8319, -0.7942, -0.8202,  ..., -0.9234, -0.9374, -0.9640],
#         [ 1.1650,  1.1759,  1.1859,  ...,  1.1132,  1.0989,  1.0882],
#         [ 0.8379,  0.9250,  0.8687,  ...,  0.7493,  0.7431,  0.7997],
#         ...,
#         [ 0.9417,  0.9712,  0.9697,  ...,  0.8406,  0.8073,  0.7732],
#         [-0.7186, -0.6465, -0.7090,  ..., -0.8516, -0.8429, -0.9225],
#         [-0.7944, -0.7487, -0.7784,  ..., -0.8742, -0.9154, -0.9013]],
#        device='cuda:0')
#
# 2 epoch
# 1801 iterations
# prob parameter: 0.652
# recon_error: 0.158
# perplexity: 8.936
# vq_loss: -5230.081
# expectation: 0.002
# ng_p tensor([[3.3677e-10, 3.4338e-10, 3.4553e-10,  ..., 1.4004e-03, 1.5013e-02,
#          5.9536e-01],
#         [1.5352e-11, 1.5654e-11, 1.5753e-11,  ..., 1.2152e-04, 2.6211e-04,
#          9.1737e-01],
#         [6.3743e-10, 6.5000e-10, 6.5410e-10,  ..., 2.2115e-03, 3.8241e-02,
#          4.2733e-01],
#         ...,
#         [9.2489e-10, 9.4303e-10, 9.4891e-10,  ..., 2.0806e-03, 1.7456e-01,
#          1.7538e-01],
#         [5.8979e-10, 6.0135e-10, 6.0509e-10,  ..., 1.6893e-03, 3.9223e-02,
#          4.5230e-01],
#         [5.0715e-10, 5.1715e-10, 5.2041e-10,  ..., 1.9411e-03, 2.5567e-02,
#          4.9634e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.6124, 0.9178, 0.4692,  ..., 0.3542, 0.4943, 0.5249], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.8544, -0.8142, -0.8411,  ..., -0.9506, -0.9656, -0.9935],
#         [ 1.1967,  1.2092,  1.2197,  ...,  1.1429,  1.1273,  1.1161],
#         [ 0.8624,  0.9527,  0.8967,  ...,  0.7691,  0.7623,  0.8215],
#         ...,
#         [ 0.9692,  1.0000,  1.0003,  ...,  0.8630,  0.8278,  0.7921],
#         [-0.7380, -0.6623, -0.7267,  ..., -0.8775, -0.8686, -0.9516],
#         [-0.8157, -0.7671, -0.7977,  ..., -0.8995, -0.9432, -0.9283]],
#        device='cuda:0')
#
# 2 epoch
# 1901 iterations
# prob parameter: 0.652
# recon_error: 0.155
# perplexity: 8.990
# vq_loss: -5250.051
# expectation: 0.002
# ng_p tensor([[2.9200e-12, 2.9776e-12, 2.9964e-12,  ..., 3.1299e-05, 4.7497e-05,
#          9.6090e-01],
#         [8.4462e-10, 8.6100e-10, 8.6629e-10,  ..., 2.7730e-03, 5.6070e-02,
#          3.9836e-01],
#         [1.3398e-11, 1.3662e-11, 1.3748e-11,  ..., 1.2162e-04, 2.6313e-04,
#          9.1608e-01],
#         ...,
#         [2.1821e-09, 2.2255e-09, 2.2398e-09,  ..., 1.2184e-02, 2.2471e-02,
#          2.9823e-01],
#         [3.2858e-09, 3.3511e-09, 3.3725e-09,  ..., 6.7450e-03, 9.3127e-02,
#          1.3149e-01],
#         [1.6382e-09, 1.6707e-09, 1.6814e-09,  ..., 7.0949e-03, 3.1320e-02,
#          3.2137e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.9610, 0.4577, 0.9165,  ..., 0.3367, 0.2391, 0.3630], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.8764, -0.8337, -0.8617,  ..., -0.9771, -0.9933, -1.0224],
#         [ 1.2280,  1.2419,  1.2527,  ...,  1.1720,  1.1552,  1.1436],
#         [ 0.8865,  0.9798,  0.9241,  ...,  0.7886,  0.7812,  0.8430],
#         ...,
#         [ 0.9963,  1.0282,  1.0303,  ...,  0.8851,  0.8479,  0.8107],
#         [-0.7570, -0.6777, -0.7442,  ..., -0.9029, -0.8938, -0.9802],
#         [-0.8364, -0.7850, -0.8168,  ..., -0.9243, -0.9704, -0.9548]],
#        device='cuda:0')
#
# 2 epoch
# 2001 iterations
# prob parameter: 0.652
# recon_error: 0.156
# perplexity: 9.009
# vq_loss: -5259.096
# expectation: 0.002
# ng_p tensor([[4.1674e-11, 4.2499e-11, 4.2773e-11,  ..., 2.9410e-04, 9.3076e-04,
#          8.5356e-01],
#         [4.1266e-12, 4.2070e-12, 4.2333e-12,  ..., 5.0868e-05, 6.7586e-05,
#          9.5313e-01],
#         [3.5598e-11, 3.6302e-11, 3.6537e-11,  ..., 2.3331e-04, 9.1779e-04,
#          8.6111e-01],
#         ...,
#         [1.1261e-12, 1.1483e-12, 1.1556e-12,  ..., 1.5061e-05, 1.7232e-05,
#          9.7468e-01],
#         [9.5898e-12, 9.7789e-12, 9.8416e-12,  ..., 9.5555e-05, 2.0360e-04,
#          9.2583e-01],
#         [5.0086e-11, 5.1073e-11, 5.1401e-11,  ..., 3.9340e-04, 1.4425e-03,
#          8.2915e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8549, 0.9533, 0.8623,  ..., 0.9747, 0.9261, 0.8311], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.8977, -0.8526, -0.8818,  ..., -1.0029, -1.0201, -1.0505],
#         [ 1.2584,  1.2737,  1.2847,  ...,  1.2004,  1.1823,  1.1703],
#         [ 0.9100,  1.0062,  0.9507,  ...,  0.8075,  0.7995,  0.8638],
#         ...,
#         [ 1.0227,  1.0557,  1.0593,  ...,  0.9066,  0.8674,  0.8287],
#         [-0.7754, -0.6926, -0.7612,  ..., -0.9275, -0.9183, -1.0079],
#         [-0.8564, -0.8024, -0.8354,  ..., -0.9483, -0.9967, -0.9805]],
#        device='cuda:0')
#
# 2 epoch
# 2101 iterations
# prob parameter: 0.652
# recon_error: 0.154
# perplexity: 8.978
# vq_loss: -5271.043
# expectation: 0.002
# ng_p tensor([[5.0039e-11, 5.1009e-11, 5.1326e-11,  ..., 5.5236e-04, 8.4515e-04,
#          8.4368e-01],
#         [4.5748e-10, 4.6638e-10, 4.6929e-10,  ..., 2.0957e-03, 2.6420e-02,
#          4.8309e-01],
#         [2.1148e-11, 2.1552e-11, 2.1682e-11,  ..., 1.5753e-05, 2.1552e-04,
#          9.4188e-01],
#         ...,
#         [8.0350e-11, 8.1927e-11, 8.2452e-11,  ..., 7.7723e-04, 2.0369e-03,
#          7.8523e-01],
#         [1.6848e-10, 1.7176e-10, 1.7284e-10,  ..., 1.3098e-03, 6.3416e-03,
#          6.8237e-01],
#         [1.1932e-12, 1.2160e-12, 1.2233e-12,  ..., 8.6842e-07, 1.1536e-05,
#          9.8626e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8452, 0.5129, 0.9421,  ..., 0.7882, 0.6904, 0.9863], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.9188, -0.8716, -0.9019,  ..., -1.0287, -1.0469, -1.0785],
#         [ 1.2891,  1.3057,  1.3168,  ...,  1.2290,  1.2096,  1.1971],
#         [ 0.9337,  1.0327,  0.9773,  ...,  0.8266,  0.8179,  0.8847],
#         ...,
#         [ 1.0494,  1.0833,  1.0885,  ...,  0.9282,  0.8870,  0.8468],
#         [-0.7936, -0.7075, -0.7783,  ..., -0.9521, -0.9427, -1.0356],
#         [-0.8764, -0.8198, -0.8540,  ..., -0.9723, -1.0231, -1.0062]],
#        device='cuda:0')
#
# 2 epoch
# 2201 iterations
# prob parameter: 0.652
# recon_error: 0.155
# perplexity: 9.033
# vq_loss: -5287.896
# expectation: 0.002
# ng_p tensor([[3.0964e-11, 3.1570e-11, 3.1770e-11,  ..., 3.1306e-04, 8.6286e-04,
#          8.5878e-01],
#         [5.5119e-10, 5.5649e-10, 5.5655e-10,  ..., 2.0877e-03, 3.2924e-02,
#          4.9971e-01],
#         [3.9390e-10, 4.0162e-10, 4.0419e-10,  ..., 1.9229e-03, 3.4496e-02,
#          4.5357e-01],
#         ...,
#         [7.5214e-11, 7.6686e-11, 7.7173e-11,  ..., 6.4846e-04, 2.5813e-03,
#          7.7910e-01],
#         [4.6616e-11, 4.7521e-11, 4.7815e-11,  ..., 3.9232e-04, 1.5688e-03,
#          8.2902e-01],
#         [6.0444e-10, 6.1625e-10, 6.2014e-10,  ..., 2.3332e-03, 8.3294e-02,
#          2.8998e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8600, 0.5351, 0.4912,  ..., 0.7825, 0.8311, 0.3779], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.9399, -0.8904, -0.9222,  ..., -1.0544, -1.0736, -1.1066],
#         [ 1.3198,  1.3377,  1.3486,  ...,  1.2575,  1.2369,  1.2239],
#         [ 0.9575,  1.0591,  1.0038,  ...,  0.8456,  0.8363,  0.9056],
#         ...,
#         [ 1.0762,  1.1109,  1.1174,  ...,  0.9498,  0.9066,  0.8648],
#         [-0.8117, -0.7224, -0.7955,  ..., -0.9767, -0.9671, -1.0632],
#         [-0.8962, -0.8371, -0.8727,  ..., -0.9962, -1.0494, -1.0319]],
#        device='cuda:0')
#
# 2 epoch
# 2301 iterations
# prob parameter: 0.652
# recon_error: 0.152
# perplexity: 9.018
# vq_loss: -5300.458
# expectation: 0.002
# ng_p tensor([[1.1261e-10, 1.1477e-10, 1.1547e-10,  ..., 6.5593e-04, 4.9402e-03,
#          7.4566e-01],
#         [1.2252e-11, 1.2489e-11, 1.2567e-11,  ..., 1.4902e-04, 2.7785e-04,
#          9.1157e-01],
#         [7.6060e-11, 7.7509e-11, 7.7975e-11,  ..., 1.0062e-04, 2.0249e-03,
#          8.5158e-01],
#         ...,
#         [4.2230e-11, 4.3046e-11, 4.3312e-11,  ..., 3.6917e-04, 1.3854e-03,
#          8.3675e-01],
#         [6.7130e-11, 6.8432e-11, 6.8860e-11,  ..., 5.7860e-04, 2.3928e-03,
#          7.8968e-01],
#         [6.8668e-13, 6.9994e-13, 7.0426e-13,  ..., 9.8826e-06, 1.2343e-05,
#          9.7973e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.7515, 0.9120, 0.8537,  ..., 0.8386, 0.7928, 0.9798], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.9605, -0.9090, -0.9421,  ..., -1.0797, -1.0999, -1.1341],
#         [ 1.3502,  1.3692,  1.3800,  ...,  1.2857,  1.2639,  1.2504],
#         [ 0.9810,  1.0852,  1.0298,  ...,  0.8643,  0.8544,  0.9262],
#         ...,
#         [ 1.1027,  1.1381,  1.1460,  ...,  0.9711,  0.9260,  0.8826],
#         [-0.8294, -0.7370, -0.8125,  ..., -1.0008, -0.9910, -1.0904],
#         [-0.9156, -0.8541, -0.8912,  ..., -1.0198, -1.0752, -1.0571]],
#        device='cuda:0')
#
# 2 epoch
# 2401 iterations
# prob parameter: 0.652
# recon_error: 0.153
# perplexity: 9.044
# vq_loss: -5307.059
# expectation: 0.002
# ng_p tensor([[2.3407e-11, 2.3857e-11, 2.4005e-11,  ..., 2.7733e-04, 6.6910e-04,
#          8.7510e-01],
#         [2.9976e-12, 3.0549e-12, 3.0734e-12,  ..., 4.1787e-05, 5.4396e-05,
#          9.6086e-01],
#         [2.6320e-10, 2.6831e-10, 2.7000e-10,  ..., 1.7159e-03, 2.1230e-02,
#          5.3222e-01],
#         ...,
#         [9.5560e-10, 9.6485e-10, 9.6494e-10,  ..., 2.7656e-03, 1.5254e-01,
#          1.8003e-01],
#         [1.8405e-11, 1.8585e-11, 1.8587e-11,  ..., 2.0416e-04, 4.5627e-04,
#          8.9279e-01],
#         [2.4046e-12, 2.4514e-12, 2.4669e-12,  ..., 3.7064e-05, 5.4778e-05,
#          9.5813e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8761, 0.9610, 0.5561,  ..., 0.3383, 0.8935, 0.9582], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-0.9810, -0.9275, -0.9621,  ..., -1.1049, -1.1260, -1.1615],
#         [ 1.3806,  1.4006,  1.4112,  ...,  1.3138,  1.2908,  1.2768],
#         [ 1.0046,  1.1112,  1.0557,  ...,  0.8830,  0.8726,  0.9468],
#         ...,
#         [ 1.1292,  1.1652,  1.1744,  ...,  0.9924,  0.9454,  0.9004],
#         [-0.8470, -0.7516, -0.8294,  ..., -1.0249, -1.0149, -1.1175],
#         [-0.9349, -0.8711, -0.9096,  ..., -1.0433, -1.1009, -1.0822]],
#        device='cuda:0')
#
# 2 epoch
# 2501 iterations
# prob parameter: 0.652
# recon_error: 0.152
# perplexity: 9.040
# vq_loss: -5307.318
# expectation: 0.002
# ng_p tensor([[2.0624e-10, 2.0826e-10, 2.0828e-10,  ..., 1.3108e-03, 1.1164e-02,
#          6.2342e-01],
#         [1.6143e-10, 1.6455e-10, 1.6559e-10,  ..., 1.3550e-03, 1.1956e-02,
#          6.1915e-01],
#         [2.7621e-10, 2.7890e-10, 2.7893e-10,  ..., 1.4834e-03, 1.9007e-02,
#          5.5574e-01],
#         ...,
#         [2.3268e-11, 2.3720e-11, 2.3873e-11,  ..., 2.3548e-04, 8.6611e-04,
#          8.6592e-01],
#         [4.9539e-10, 5.0388e-10, 5.0506e-10,  ..., 2.2417e-03, 5.1655e-02,
#          3.7129e-01],
#         [6.1700e-10, 6.2891e-10, 6.2904e-10,  ..., 2.3445e-03, 9.7208e-02,
#          2.5667e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.6365, 0.6331, 0.5771,  ..., 0.8671, 0.4271, 0.3589], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.0012, -0.9460, -0.9820,  ..., -1.1300, -1.1520, -1.1887],
#         [ 1.4110,  1.4320,  1.4423,  ...,  1.3419,  1.3177,  1.3032],
#         [ 1.0283,  1.1371,  1.0816,  ...,  0.9016,  0.8907,  0.9673],
#         ...,
#         [ 1.1558,  1.1923,  1.2027,  ...,  1.0137,  0.9648,  0.9181],
#         [-0.8644, -0.7662, -0.8463,  ..., -1.0489, -1.0385, -1.1443],
#         [-0.9539, -0.8880, -0.9280,  ..., -1.0667, -1.1264, -1.1071]],
#        device='cuda:0')
#
# 2 epoch
# 2601 iterations
# prob parameter: 0.652
# recon_error: 0.152
# perplexity: 9.089
# vq_loss: -5312.560
# expectation: 0.002
# ng_p tensor([[2.2943e-10, 2.3377e-10, 2.3517e-10,  ..., 5.1009e-04, 1.4120e-02,
#          6.6611e-01],
#         [4.3505e-12, 4.4338e-12, 4.4610e-12,  ..., 6.4679e-05, 1.3169e-04,
#          9.4162e-01],
#         [4.9696e-10, 5.0644e-10, 5.0952e-10,  ..., 2.1355e-03, 1.0054e-01,
#          2.8092e-01],
#         ...,
#         [1.0729e-11, 1.0935e-11, 1.1002e-11,  ..., 1.4503e-04, 3.6304e-04,
#          9.0808e-01],
#         [1.0850e-11, 1.1058e-11, 1.1127e-11,  ..., 1.9903e-04, 2.8549e-04,
#          9.0616e-01],
#         [2.5198e-11, 2.5360e-11, 2.5444e-11,  ..., 2.8601e-04, 6.3661e-04,
#          8.7173e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.6809, 0.9418, 0.3857,  ..., 0.9086, 0.9067, 0.8727], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.0212, -0.9642, -1.0018,  ..., -1.1548, -1.1776, -1.2157],
#         [ 1.4412,  1.4630,  1.4729,  ...,  1.3697,  1.3444,  1.3293],
#         [ 1.0518,  1.1628,  1.1070,  ...,  0.9201,  0.9087,  0.9877],
#         ...,
#         [ 1.1822,  1.2191,  1.2305,  ...,  1.0347,  0.9840,  0.9356],
#         [-0.8816, -0.7806, -0.8632,  ..., -1.0727, -1.0619, -1.1709],
#         [-0.9727, -0.9048, -0.9463,  ..., -1.0898, -1.1516, -1.1318]],
#        device='cuda:0')
#
# 2 epoch
# 2701 iterations
# prob parameter: 0.652
# recon_error: 0.152
# perplexity: 9.064
# vq_loss: -5319.907
# expectation: 0.002
# ng_p tensor([[2.4353e-10, 2.4824e-10, 2.4983e-10,  ..., 1.5971e-03, 3.0066e-02,
#          4.8637e-01],
#         [1.1803e-11, 1.2030e-11, 1.2107e-11,  ..., 1.9647e-04, 4.8569e-04,
#          8.9361e-01],
#         [6.1330e-10, 6.1927e-10, 6.1932e-10,  ..., 2.3539e-03, 1.4856e-01,
#          1.9003e-01],
#         ...,
#         [8.0585e-11, 8.2142e-11, 8.2662e-11,  ..., 9.9397e-04, 4.7384e-03,
#          7.2348e-01],
#         [3.1699e-10, 3.2312e-10, 3.2519e-10,  ..., 1.9501e-03, 4.0549e-02,
#          4.2567e-01],
#         [7.1373e-11, 7.2744e-11, 7.3199e-11,  ..., 7.7146e-04, 4.6672e-03,
#          7.3513e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.5192, 0.8943, 0.3436,  ..., 0.7295, 0.4697, 0.7409], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.0411, -0.9825, -1.0216,  ..., -1.1796, -1.2032, -1.2425],
#         [ 1.4714,  1.4939,  1.5033,  ...,  1.3975,  1.3711,  1.3554],
#         [ 1.0753,  1.1883,  1.1323,  ...,  0.9385,  0.9266,  1.0080],
#         ...,
#         [ 1.2087,  1.2458,  1.2583,  ...,  1.0557,  1.0032,  0.9531],
#         [-0.8986, -0.7950, -0.8800,  ..., -1.0964, -1.0852, -1.1974],
#         [-0.9914, -0.9215, -0.9647,  ..., -1.1129, -1.1767, -1.1564]],
#        device='cuda:0')
#
# 2 epoch
# 2801 iterations
# prob parameter: 0.652
# recon_error: 0.152
# perplexity: 9.041
# vq_loss: -5322.461
# expectation: 0.002
# ng_p tensor([[4.9868e-10, 5.0832e-10, 5.1163e-10,  ..., 2.0827e-03, 1.3733e-01,
#          2.0630e-01],
#         [4.4097e-10, 4.4525e-10, 4.4529e-10,  ..., 2.2990e-03, 5.5212e-02,
#          3.6988e-01],
#         [4.0396e-11, 4.0786e-11, 4.0790e-11,  ..., 4.6440e-04, 1.2960e-03,
#          8.3474e-01],
#         ...,
#         [1.2087e-10, 1.2319e-10, 1.2397e-10,  ..., 1.1427e-03, 8.4823e-03,
#          6.5946e-01],
#         [4.0608e-12, 4.1371e-12, 4.1616e-12,  ..., 5.2679e-06, 6.4526e-05,
#          9.6887e-01],
#         [4.3096e-10, 4.3907e-10, 4.4169e-10,  ..., 1.4902e-03, 5.3540e-02,
#          4.4495e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3484, 0.4293, 0.8366,  ..., 0.6696, 0.9689, 0.5003], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.0610, -1.0009, -1.0416,  ..., -1.2045, -1.2287, -1.2694],
#         [ 1.5018,  1.5250,  1.5338,  ...,  1.4254,  1.3980,  1.3817],
#         [ 1.0991,  1.2140,  1.1577,  ...,  0.9570,  0.9447,  1.0285],
#         ...,
#         [ 1.2353,  1.2726,  1.2861,  ...,  1.0768,  1.0225,  0.9708],
#         [-0.9156, -0.8094, -0.8970,  ..., -1.1202, -1.1085, -1.2239],
#         [-1.0100, -0.9383, -0.9831,  ..., -1.1361, -1.2018, -1.1810]],
#        device='cuda:0')
#
# 2 epoch
# 2901 iterations
# prob parameter: 0.652
# recon_error: 0.153
# perplexity: 9.105
# vq_loss: -5331.322
# expectation: 0.002
# ng_p tensor([[1.6155e-10, 1.6310e-10, 1.6312e-10,  ..., 1.4631e-03, 8.3153e-03,
#          6.5714e-01],
#         [2.9984e-10, 3.0273e-10, 3.0276e-10,  ..., 2.2763e-03, 1.9862e-02,
#          5.3235e-01],
#         [6.9210e-12, 6.9879e-12, 6.9885e-12,  ..., 1.1615e-04, 1.5901e-04,
#          9.2947e-01],
#         ...,
#         [4.8503e-10, 4.9423e-10, 4.9722e-10,  ..., 2.5850e-03, 1.3748e-01,
#          2.1522e-01],
#         [4.3828e-10, 4.4659e-10, 4.4930e-10,  ..., 2.6737e-03, 8.8030e-02,
#          2.9607e-01],
#         [6.1296e-13, 6.2454e-13, 6.2830e-13,  ..., 1.2483e-05, 1.5880e-05,
#          9.7886e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.6674, 0.5555, 0.9298,  ..., 0.3578, 0.3889, 0.9789], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.0807, -1.0192, -1.0616,  ..., -1.2293, -1.2542, -1.2962],
#         [ 1.5322,  1.5559,  1.5642,  ...,  1.4533,  1.4250,  1.4079],
#         [ 1.1229,  1.2395,  1.1829,  ...,  0.9755,  0.9629,  1.0490],
#         ...,
#         [ 1.2621,  1.2993,  1.3137,  ...,  1.0979,  1.0419,  0.9884],
#         [-0.9325, -0.8239, -0.9141,  ..., -1.1440, -1.1317, -1.2504],
#         [-1.0286, -0.9551, -1.0016,  ..., -1.1592, -1.2269, -1.2056]],
#        device='cuda:0')
#
# 3 epoch
# 3001 iterations
# prob parameter: 0.652
# recon_error: 0.152
# perplexity: 9.068
# vq_loss: -5330.543
# expectation: 0.002
# ng_p tensor([[3.5780e-10, 3.6461e-10, 3.6686e-10,  ..., 2.7263e-03, 5.4976e-02,
#          3.6591e-01],
#         [1.9577e-10, 1.9766e-10, 1.9767e-10,  ..., 1.7878e-03, 1.6200e-02,
#          5.7932e-01],
#         [3.5573e-10, 3.6253e-10, 3.6480e-10,  ..., 2.0507e-03, 1.0254e-01,
#          2.6691e-01],
#         ...,
#         [2.3605e-11, 2.4053e-11, 2.4200e-11,  ..., 3.3039e-04, 1.0421e-03,
#          8.5398e-01],
#         [4.5871e-10, 4.6739e-10, 4.7021e-10,  ..., 2.1539e-03, 1.6950e-01,
#          1.8556e-01],
#         [1.9339e-10, 1.9710e-10, 1.9837e-10,  ..., 1.5853e-03, 2.2919e-02,
#          5.2606e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.4255, 0.5981, 0.3738,  ..., 0.8554, 0.3596, 0.5516], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.1003, -1.0376, -1.0816,  ..., -1.2542, -1.2796, -1.3230],
#         [ 1.5628,  1.5868,  1.5946,  ...,  1.4813,  1.4520,  1.4344],
#         [ 1.1469,  1.2650,  1.2082,  ...,  0.9940,  0.9811,  1.0696],
#         ...,
#         [ 1.2890,  1.3261,  1.3415,  ...,  1.1191,  1.0614,  1.0061],
#         [-0.9494, -0.8385, -0.9311,  ..., -1.1678, -1.1548, -1.2767],
#         [-1.0470, -0.9720, -1.0201,  ..., -1.1823, -1.2518, -1.2300]],
#        device='cuda:0')
#
# 3 epoch
# 3101 iterations
# prob parameter: 0.652
# recon_error: 0.152
# perplexity: 9.026
# vq_loss: -5341.754
# expectation: 0.002
# ng_p tensor([[6.2933e-09, 6.4098e-09, 6.4471e-09,  ..., 2.8918e-03, 1.6094e-02,
#          4.0072e-01],
#         [5.9214e-12, 6.0317e-12, 6.0672e-12,  ..., 8.5732e-06, 1.0822e-04,
#          9.6052e-01],
#         [2.7074e-10, 2.7590e-10, 2.7762e-10,  ..., 2.0465e-03, 3.8379e-02,
#          4.3706e-01],
#         ...,
#         [1.3502e-10, 1.3633e-10, 1.3634e-10,  ..., 1.2388e-03, 1.2612e-02,
#          6.2434e-01],
#         [3.7009e-10, 3.7720e-10, 3.7967e-10,  ..., 2.2069e-03, 8.6576e-02,
#          2.9338e-01],
#         [1.9838e-10, 2.0219e-10, 2.0254e-10,  ..., 1.7630e-03, 2.3041e-02,
#          5.2603e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.4213, 0.9606, 0.4789,  ..., 0.6388, 0.3844, 0.5518], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.1201, -1.0563, -1.1019,  ..., -1.2792, -1.3051, -1.3498],
#         [ 1.5937,  1.6180,  1.6252,  ...,  1.5094,  1.4793,  1.4610],
#         [ 1.1711,  1.2906,  1.2336,  ...,  1.0127,  0.9995,  1.0904],
#         ...,
#         [ 1.3162,  1.3530,  1.3694,  ...,  1.1404,  1.0811,  1.0240],
#         [-0.9662, -0.8532, -0.9484,  ..., -1.1918, -1.1781, -1.3033],
#         [-1.0655, -0.9890, -1.0388,  ..., -1.2057, -1.2769, -1.2546]],
#        device='cuda:0')
#
# 3 epoch
# 3201 iterations
# prob parameter: 0.652
# recon_error: 0.149
# perplexity: 9.064
# vq_loss: -5344.853
# expectation: 0.002
# ng_p tensor([[5.3395e-10, 5.3907e-10, 5.3912e-10,  ..., 2.9750e-03, 7.4587e-02,
#          3.1361e-01],
#         [3.8670e-12, 3.9036e-12, 3.9040e-12,  ..., 5.5568e-06, 1.1432e-04,
#          9.6368e-01],
#         [2.1966e-12, 2.2175e-12, 2.2177e-12,  ..., 3.0833e-05, 5.8833e-05,
#          9.6317e-01],
#         ...,
#         [1.4542e-11, 1.4819e-11, 1.4913e-11,  ..., 2.9823e-04, 7.1181e-04,
#          8.7168e-01],
#         [4.6381e-10, 4.6829e-10, 4.6833e-10,  ..., 2.1469e-03, 1.5686e-01,
#          1.8987e-01],
#         [2.8492e-10, 2.9036e-10, 2.9221e-10,  ..., 2.3707e-03, 6.4882e-02,
#          3.4958e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3933, 0.9638, 0.9633,  ..., 0.8728, 0.3514, 0.4185], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.1401, -1.0753, -1.1226,  ..., -1.3048, -1.3310, -1.3772],
#         [ 1.6252,  1.6496,  1.6562,  ...,  1.5381,  1.5072,  1.4882],
#         [ 1.1959,  1.3167,  1.2594,  ...,  1.0316,  1.0184,  1.1117],
#         ...,
#         [ 1.3440,  1.3803,  1.3977,  ...,  1.1621,  1.1012,  1.0423],
#         [-0.9834, -0.8683, -0.9660,  ..., -1.2163, -1.2017, -1.3303],
#         [-1.0843, -1.0065, -1.0579,  ..., -1.2294, -1.3023, -1.2796]],
#        device='cuda:0')
#
# 3 epoch
# 3301 iterations
# prob parameter: 0.652
# recon_error: 0.150
# perplexity: 9.088
# vq_loss: -5348.496
# expectation: 0.002
# ng_p tensor([[2.9879e-13, 3.0434e-13, 3.0612e-13,  ..., 5.2102e-07, 7.8198e-06,
#          9.8989e-01],
#         [1.2124e-10, 1.2351e-10, 1.2424e-10,  ..., 1.3608e-03, 1.2573e-02,
#          6.5709e-01],
#         [3.0284e-10, 3.0850e-10, 3.1032e-10,  ..., 2.4334e-03, 5.6511e-02,
#          4.2513e-01],
#         ...,
#         [3.2060e-10, 3.2658e-10, 3.2851e-10,  ..., 2.4828e-03, 6.8414e-02,
#          3.9219e-01],
#         [1.4039e-13, 1.4306e-13, 1.4397e-13,  ..., 3.9015e-06, 4.3520e-06,
#          9.8748e-01],
#         [5.2443e-11, 5.3424e-11, 5.3740e-11,  ..., 7.1227e-04, 3.7995e-03,
#          7.8228e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.9899, 0.6712, 0.4845,  ..., 0.4635, 0.9875, 0.7869], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.1604, -1.0947, -1.1436,  ..., -1.3307, -1.3572, -1.4048],
#         [ 1.6572,  1.6816,  1.6875,  ...,  1.5671,  1.5356,  1.5158],
#         [ 1.2210,  1.3430,  1.2854,  ...,  1.0508,  1.0375,  1.1332],
#         ...,
#         [ 1.3722,  1.4079,  1.4263,  ...,  1.1841,  1.1217,  1.0609],
#         [-1.0008, -0.8836, -0.9840,  ..., -1.2412, -1.2256, -1.3576],
#         [-1.1033, -1.0242, -1.0774,  ..., -1.2536, -1.3280, -1.3050]],
#        device='cuda:0')
#
# 3 epoch
# 3401 iterations
# prob parameter: 0.652
# recon_error: 0.150
# perplexity: 9.107
# vq_loss: -5359.325
# expectation: 0.002
# ng_p tensor([[1.6881e-12, 1.7039e-12, 1.7041e-12,  ..., 2.2295e-06, 3.1275e-05,
#          9.7892e-01],
#         [1.2318e-10, 1.2434e-10, 1.2436e-10,  ..., 1.2092e-03, 8.2561e-03,
#          6.9717e-01],
#         [1.0095e-10, 1.0190e-10, 1.0191e-10,  ..., 1.0248e-03, 6.5289e-03,
#          7.2481e-01],
#         ...,
#         [6.7997e-12, 6.9286e-12, 6.9726e-12,  ..., 1.8269e-04, 3.0183e-04,
#          9.0838e-01],
#         [6.8362e-12, 6.9647e-12, 7.0070e-12,  ..., 1.4403e-04, 2.7455e-04,
#          9.1653e-01],
#         [7.2631e-11, 7.4016e-11, 7.4498e-11,  ..., 1.0769e-03, 5.1724e-03,
#          7.1106e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.9790, 0.7068, 0.7325,  ..., 0.9089, 0.9170, 0.7177], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.1807, -1.1142, -1.1648,  ..., -1.3567, -1.3834, -1.4325],
#         [ 1.6893,  1.7136,  1.7189,  ...,  1.5963,  1.5641,  1.5436],
#         [ 1.2463,  1.3693,  1.3116,  ...,  1.0701,  1.0568,  1.1549],
#         ...,
#         [ 1.4006,  1.4356,  1.4551,  ...,  1.2062,  1.1424,  1.0796],
#         [-1.0181, -0.8991, -1.0021,  ..., -1.2662, -1.2495, -1.3849],
#         [-1.1224, -1.0421, -1.0969,  ..., -1.2778, -1.3538, -1.3303]],
#        device='cuda:0')
#
# 3 epoch
# 3501 iterations
# prob parameter: 0.652
# recon_error: 0.150
# perplexity: 9.118
# vq_loss: -5349.818
# expectation: 0.002
# ng_p tensor([[1.2650e-10, 1.2768e-10, 1.2770e-10,  ..., 1.3282e-04, 1.3443e-03,
#          8.5033e-01],
#         [6.3955e-10, 6.4554e-10, 6.4561e-10,  ..., 5.2481e-04, 4.4139e-03,
#          7.1582e-01],
#         [9.4026e-12, 9.4911e-12, 9.4921e-12,  ..., 1.9741e-05, 3.8384e-04,
#          9.3525e-01],
#         ...,
#         [2.9550e-12, 3.0109e-12, 3.0300e-12,  ..., 8.0030e-05, 1.5055e-04,
#          9.3661e-01],
#         [4.4297e-12, 4.5123e-12, 4.5392e-12,  ..., 1.0506e-04, 1.4523e-04,
#          9.3801e-01],
#         [2.1329e-10, 2.1728e-10, 2.1858e-10,  ..., 1.7734e-03, 3.4572e-02,
# ...
#         ...,
#         [ 1.6079,  1.6328,  1.6624,  ...,  1.3661,  1.2943,  1.2171],
#         [-1.1428, -1.0143, -1.1337,  ..., -1.4481, -1.4206, -1.5806],
#         [-1.2588, -1.1743, -1.2390,  ..., -1.4538, -1.5378, -1.5116]],
#        device='cuda:0')
#
# 3 epoch
# 4201 iterations
# prob parameter: 0.652
# recon_error: 0.149
# perplexity: 9.113
# vq_loss: -5409.117
# expectation: 0.002
# ng_p tensor([[2.3912e-10, 2.4357e-10, 2.4505e-10,  ..., 2.0940e-03, 1.0823e-01,
#          2.6372e-01],
#         [1.4621e-11, 1.4894e-11, 1.4987e-11,  ..., 3.5895e-04, 1.3103e-03,
#          8.4340e-01],
#         [2.0727e-10, 2.1110e-10, 2.1235e-10,  ..., 1.6427e-03, 4.4860e-02,
#          4.3984e-01],
#         ...,
#         [2.3977e-10, 2.4423e-10, 2.4568e-10,  ..., 3.5388e-03, 2.5346e-02,
#          4.7910e-01],
#         [3.7373e-10, 3.8069e-10, 3.8300e-10,  ..., 3.4104e-03, 8.0778e-02,
#          2.7461e-01],
#         [3.7654e-11, 3.8359e-11, 3.8603e-11,  ..., 9.2846e-04, 3.1546e-03,
#          7.5613e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3765, 0.8452, 0.4878,  ..., 0.5093, 0.3621, 0.7605], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.3480, -1.2802, -1.3416,  ..., -1.5735, -1.5981, -1.6596],
#         [ 1.9566,  1.9748,  1.9778,  ...,  1.8377,  1.8036,  1.7768],
#         [ 1.4583,  1.5834,  1.5279,  ...,  1.2297,  1.2199,  1.3381],
#         ...,
#         [ 1.6386,  1.6615,  1.6928,  ...,  1.3898,  1.3171,  1.2376],
#         [-1.1612, -1.0318, -1.1533,  ..., -1.4751, -1.4457, -1.6094],
#         [-1.2790, -1.1942, -1.2602,  ..., -1.4799, -1.5647, -1.5382]],
#        device='cuda:0')
#
# 3 epoch
# 4301 iterations
# prob parameter: 0.652
# recon_error: 0.149
# perplexity: 9.101
# vq_loss: -5417.068
# expectation: 0.002
# ng_p tensor([[1.3740e-11, 1.3870e-11, 1.3870e-11,  ..., 3.3295e-04, 1.1797e-03,
#          8.5319e-01],
#         [4.1435e-11, 4.2205e-11, 4.2465e-11,  ..., 9.4397e-04, 4.1432e-03,
#          7.4126e-01],
#         [2.3461e-10, 2.3888e-10, 2.4024e-10,  ..., 2.7891e-04, 2.1353e-03,
#          7.9853e-01],
#         ...,
#         [2.1871e-11, 2.2078e-11, 2.2079e-11,  ..., 5.6039e-04, 1.7382e-03,
#          8.1560e-01],
#         [9.1123e-13, 9.2816e-13, 9.3389e-13,  ..., 3.9389e-05, 4.3163e-05,
#          9.6169e-01],
#         [7.5396e-11, 7.6810e-11, 7.7045e-11,  ..., 1.2488e-03, 1.1108e-02,
#          6.3470e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8548, 0.7466, 0.8011,  ..., 0.8180, 0.9618, 0.6477], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.3696, -1.3022, -1.3646,  ..., -1.6016, -1.6255, -1.6886],
#         [ 1.9910,  2.0079,  2.0109,  ...,  1.8688,  1.8348,  1.8072],
#         [ 1.4857,  1.6106,  1.5557,  ...,  1.2502,  1.2412,  1.3621],
#         ...,
#         [ 1.6693,  1.6903,  1.7233,  ...,  1.4135,  1.3400,  1.2583],
#         [-1.1798, -1.0494, -1.1730,  ..., -1.5022, -1.4708, -1.6381],
#         [-1.2992, -1.2144, -1.2814,  ..., -1.5061, -1.5916, -1.5648]],
#        device='cuda:0')
#
# 3 epoch
# 4401 iterations
# prob parameter: 0.652
# recon_error: 0.147
# perplexity: 9.149
# vq_loss: -5428.490
# expectation: 0.002
# ng_p tensor([[4.9428e-11, 5.0350e-11, 5.0671e-11,  ..., 1.1209e-03, 8.1580e-03,
#          6.7686e-01],
#         [1.2153e-10, 1.2268e-10, 1.2268e-10,  ..., 1.9500e-03, 3.0056e-02,
#          4.9613e-01],
#         [6.9248e-12, 7.0527e-12, 7.0954e-12,  ..., 1.7687e-04, 4.6316e-04,
#          8.9948e-01],
#         ...,
#         [1.4310e-10, 1.4445e-10, 1.4445e-10,  ..., 2.1563e-03, 3.9872e-02,
#          4.4725e-01],
#         [3.1958e-10, 3.2257e-10, 3.2258e-10,  ..., 2.9634e-03, 1.5348e-01,
#          1.9182e-01],
#         [7.0887e-14, 7.1557e-14, 7.1559e-14,  ..., 3.4941e-06, 3.5468e-06,
#          9.8882e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.6866, 0.5292, 0.9002,  ..., 0.4905, 0.3512, 0.9888], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.3916, -1.3245, -1.3879,  ..., -1.6300, -1.6532, -1.7180],
#         [ 2.0256,  2.0413,  2.0443,  ...,  1.9002,  1.8664,  1.8379],
#         [ 1.5133,  1.6378,  1.5837,  ...,  1.2711,  1.2629,  1.3863],
#         ...,
#         [ 1.7003,  1.7191,  1.7541,  ...,  1.4375,  1.3633,  1.2793],
#         [-1.1986, -1.0674, -1.1930,  ..., -1.5296, -1.4961, -1.6672],
#         [-1.3198, -1.2348, -1.3029,  ..., -1.5325, -1.6188, -1.5917]],
#        device='cuda:0')
#
# 4 epoch
# 4501 iterations
# prob parameter: 0.652
# recon_error: 0.147
# perplexity: 9.145
# vq_loss: -5434.942
# expectation: 0.002
# ng_p tensor([[1.9079e-11, 1.9434e-11, 1.9556e-11,  ..., 5.6635e-04, 2.2807e-03,
#          8.0051e-01],
#         [1.2997e-10, 1.3238e-10, 1.3318e-10,  ..., 1.7914e-03, 3.8438e-02,
#          4.5959e-01],
#         [9.9352e-11, 1.0119e-10, 1.0180e-10,  ..., 1.5155e-03, 2.3963e-02,
#          5.3934e-01],
#         ...,
#         [8.9489e-11, 9.0923e-11, 9.1162e-11,  ..., 1.7610e-03, 2.0134e-02,
#          5.4980e-01],
#         [6.9069e-14, 7.0355e-14, 7.0800e-14,  ..., 3.8327e-06, 3.8873e-06,
#          9.8816e-01],
#         [1.0935e-10, 1.1139e-10, 1.1210e-10,  ..., 1.8432e-03, 3.3120e-02,
#          4.7625e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.8035, 0.5011, 0.5658,  ..., 0.5726, 0.9882, 0.5124], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.4134, -1.3468, -1.4111,  ..., -1.6582, -1.6807, -1.7471],
#         [ 2.0599,  2.0744,  2.0775,  ...,  1.9314,  1.8978,  1.8684],
#         [ 1.5408,  1.6648,  1.6116,  ...,  1.2918,  1.2845,  1.4105],
#         ...,
#         [ 1.7310,  1.7477,  1.7848,  ...,  1.4614,  1.3864,  1.3002],
#         [-1.2173, -1.0853, -1.2129,  ..., -1.5569, -1.5212, -1.6960],
#         [-1.3403, -1.2553, -1.3243,  ..., -1.5589, -1.6458, -1.6184]],
#        device='cuda:0')
#
# 4 epoch
# 4601 iterations
# prob parameter: 0.652
# recon_error: 0.147
# perplexity: 9.103
# vq_loss: -5451.367
# expectation: 0.002
# ng_p tensor([[3.0776e-12, 3.1064e-12, 3.1065e-12,  ..., 1.0495e-04, 2.3198e-04,
#          9.2657e-01],
#         [7.2418e-12, 7.3094e-12, 7.3095e-12,  ..., 2.6713e-04, 4.7738e-04,
#          8.9117e-01],
#         [6.1269e-12, 6.1842e-12, 6.1843e-12,  ..., 2.4923e-04, 3.5593e-04,
#          9.0010e-01],
#         ...,
#         [2.1960e-11, 2.2366e-11, 2.2503e-11,  ..., 6.4499e-04, 2.9224e-03,
#          7.8561e-01],
#         [2.6592e-12, 2.7088e-12, 2.7263e-12,  ..., 9.3774e-05, 2.3455e-04,
#          9.2628e-01],
#         [4.1254e-11, 4.2022e-11, 4.2289e-11,  ..., 1.1275e-03, 5.6711e-03,
#          7.0715e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.9269, 0.8920, 0.9008,  ..., 0.7894, 0.9266, 0.7143], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.4352, -1.3690, -1.4341,  ..., -1.6863, -1.7079, -1.7761],
#         [ 2.0940,  2.1071,  2.1104,  ...,  1.9624,  1.9290,  1.8988],
#         [ 1.5680,  1.6915,  1.6393,  ...,  1.3124,  1.3060,  1.4345],
#         ...,
#         [ 1.7615,  1.7761,  1.8151,  ...,  1.4852,  1.4095,  1.3210],
#         [-1.2360, -1.1033, -1.2326,  ..., -1.5840, -1.5462, -1.7246],
#         [-1.3606, -1.2757, -1.3456,  ..., -1.5850, -1.6726, -1.6449]],
#        device='cuda:0')
#
# 4 epoch
# 4701 iterations
# prob parameter: 0.652
# recon_error: 0.146
# perplexity: 9.125
# vq_loss: -5464.486
# expectation: 0.002
# ng_p tensor([[3.0755e-13, 3.1325e-13, 3.1523e-13,  ..., 1.5407e-05, 2.0640e-05,
#          9.7473e-01],
#         [1.5948e-10, 1.6242e-10, 1.6340e-10,  ..., 2.0049e-03, 4.7562e-02,
#          4.1327e-01],
#         [1.3458e-11, 1.3707e-11, 1.3794e-11,  ..., 3.9491e-04, 1.7990e-03,
#          8.2685e-01],
#         ...,
#         [1.9092e-11, 1.9269e-11, 1.9269e-11,  ..., 5.4530e-04, 1.7595e-03,
#          8.2912e-01],
#         [5.1170e-11, 5.1648e-11, 5.1649e-11,  ..., 1.0393e-03, 7.5962e-03,
#          6.8741e-01],
#         [4.9417e-12, 4.9877e-12, 4.9878e-12,  ..., 1.7330e-04, 3.5756e-04,
#          9.0834e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.9748, 0.4646, 0.8292,  ..., 0.8315, 0.6965, 0.9089], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.4575, -1.3918, -1.4577,  ..., -1.7149, -1.7357, -1.8056],
#         [ 2.1287,  2.1404,  2.1440,  ...,  1.9941,  1.9610,  1.9298],
#         [ 1.5958,  1.7187,  1.6676,  ...,  1.3334,  1.3281,  1.4590],
#         ...,
#         [ 1.7926,  1.8050,  1.8462,  ...,  1.5094,  1.4332,  1.3423],
#         [-1.2551, -1.1217, -1.2529,  ..., -1.6118, -1.5716, -1.7538],
#         [-1.3815, -1.2967, -1.3674,  ..., -1.6118, -1.6999, -1.6720]],
#        device='cuda:0')
#
# 4 epoch
# 4801 iterations
# prob parameter: 0.652
# recon_error: 0.147
# perplexity: 9.177
# vq_loss: -5472.216
# expectation: 0.002
# ng_p tensor([[1.9938e-10, 2.0307e-10, 2.0437e-10,  ..., 2.3038e-03, 1.5450e-01,
#          1.8870e-01],
#         [7.3385e-13, 7.4738e-13, 7.5198e-13,  ..., 3.6795e-05, 5.7377e-05,
#          9.6017e-01],
#         [3.2886e-10, 3.3486e-10, 3.3685e-10,  ..., 3.6149e-03, 1.6504e-01,
#          1.7383e-01],
#         ...,
#         [1.4921e-10, 1.5001e-10, 1.5062e-10,  ..., 2.3588e-03, 4.5146e-02,
#          4.1067e-01],
#         [1.8308e-10, 1.8365e-10, 1.8481e-10,  ..., 2.4085e-03, 8.6855e-02,
#          2.9652e-01],
#         [3.1911e-12, 3.2208e-12, 3.2209e-12,  ..., 1.1293e-04, 2.6954e-04,
#          9.2287e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.3485, 0.9603, 0.3451,  ..., 0.4599, 0.3881, 0.9233], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.4803, -1.4152, -1.4818,  ..., -1.7441, -1.7640, -1.8357],
#         [ 2.1637,  2.1742,  2.1779,  ...,  2.0263,  1.9934,  1.9613],
#         [ 1.6238,  1.7463,  1.6962,  ...,  1.3548,  1.3505,  1.4840],
#         ...,
#         [ 1.8241,  1.8341,  1.8776,  ...,  1.5341,  1.4572,  1.3639],
#         [-1.2747, -1.1406, -1.2735,  ..., -1.6400, -1.5975, -1.7836],
#         [-1.4029, -1.3181, -1.3896,  ..., -1.6390, -1.7277, -1.6996]],
#        device='cuda:0')
#
# 4 epoch
# 4901 iterations
# prob parameter: 0.652
# recon_error: 0.147
# perplexity: 9.142
# vq_loss: -5476.387
# expectation: 0.002
# ng_p tensor([[1.3992e-10, 1.4122e-10, 1.4122e-10,  ..., 2.2157e-03, 5.4260e-02,
#          3.9145e-01],
#         [1.9436e-10, 1.9617e-10, 1.9618e-10,  ..., 2.3419e-03, 1.3992e-01,
#          2.1196e-01],
#         [1.2718e-12, 1.2947e-12, 1.2953e-12,  ..., 6.5355e-05, 9.4246e-05,
#          9.4703e-01],
#         ...,
#         [1.7048e-11, 1.7362e-11, 1.7468e-11,  ..., 5.6350e-04, 2.1707e-03,
#          8.0580e-01],
#         [1.9492e-10, 1.9849e-10, 1.9966e-10,  ..., 2.1276e-03, 1.4721e-01,
#          2.2860e-01],
#         [1.4823e-12, 1.5091e-12, 1.5176e-12,  ..., 3.7597e-06, 3.9429e-05,
#          9.7565e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.4497, 0.3571, 0.9472,  ..., 0.8087, 0.3796, 0.9757], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.5033, -1.4387, -1.5059,  ..., -1.7734, -1.7923, -1.8659],
#         [ 2.1989,  2.2080,  2.2121,  ...,  2.0585,  2.0261,  1.9929],
#         [ 1.6520,  1.7738,  1.7249,  ...,  1.3763,  1.3731,  1.5090],
#         ...,
#         [ 1.8556,  1.8634,  1.9091,  ...,  1.5589,  1.4815,  1.3856],
#         [-1.2944, -1.1596, -1.2942,  ..., -1.6683, -1.6234, -1.8134],
#         [-1.4244, -1.3396, -1.4119,  ..., -1.6664, -1.7555, -1.7273]],
#        device='cuda:0')
#
# 4 epoch
# 5001 iterations
# prob parameter: 0.652
# recon_error: 0.148
# perplexity: 9.165
# vq_loss: -5481.806
# expectation: 0.002
# ng_p tensor([[2.8193e-11, 2.8706e-11, 2.8874e-11,  ..., 3.1893e-04, 4.2940e-03,
#          7.8154e-01],
#         [7.2722e-11, 7.4059e-11, 7.4517e-11,  ..., 1.4558e-03, 2.3736e-02,
#          5.3889e-01],
#         [1.5955e-10, 1.6247e-10, 1.6343e-10,  ..., 2.4148e-03, 7.3234e-02,
#          3.5747e-01],
#         ...,
#         [1.0321e-10, 1.0507e-10, 1.0567e-10,  ..., 3.8883e-04, 6.0279e-03,
#          7.5101e-01],
#         [1.9018e-13, 1.9361e-13, 1.9470e-13,  ..., 3.9792e-07, 3.6839e-06,
#          9.9210e-01],
#         [7.8305e-11, 7.9721e-11, 8.0173e-11,  ..., 2.7985e-04, 4.1104e-03,
#          7.8861e-01]], device='cuda:0', grad_fn=<SortBackward0>)
# ng_p sum tensor([0.7864, 0.5651, 0.4343,  ..., 0.7576, 0.9921, 0.7931], device='cuda:0',
#        grad_fn=<SumBackward1>)
# W tensor([[-1.5262, -1.4622, -1.5300,  ..., -1.8027, -1.8206, -1.8960],
#         [ 2.2340,  2.2417,  2.2462,  ...,  2.0908,  2.0588,  2.0246],
#         [ 1.6801,  1.8013,  1.7538,  ...,  1.3978,  1.3958,  1.5342],
#         ...,
#         [ 1.8872,  1.8926,  1.9407,  ...,  1.5837,  1.5058,  1.4074],
#         [-1.3142, -1.1786, -1.3149,  ..., -1.6967, -1.6493, -1.8433],
#         [-1.4459, -1.3613, -1.4342,  ..., -1.6937, -1.7832, -1.7550]],
#        device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-063c9e3f9bda> in <module>()
#       7 num_training_updates = 15100
#       8 for i in xrange(num_training_updates):
# ----> 9     (data, _) = next(iter(training_loader))
#      10     epoch = i // 1500
#      11     data = data.to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     118
#     119         if self.transform is not None:
# --> 120             img = self.transform(img)
#     121
#     122         if self.target_transform is not None:
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in forward(self, tensor)
#     219             Tensor: Normalized Tensor image.
#     220         """
# --> 221         return F.normalize(tensor, self.mean, self.std, self.inplace)
#     222
#     223     def __repr__(self):
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py in normalize(tensor, mean, std, inplace)
#     327     mean = torch.as_tensor(mean, dtype=dtype, device=tensor.device)
#     328     std = torch.as_tensor(std, dtype=dtype, device=tensor.device)
# --> 329     if (std == 0).any():
#     330         raise ValueError('std evaluated to zero after conversion to {}, leading to division by zero.'.format(dtype))
#     331     if mean.ndim == 1:
#
# KeyboardInterrupt:

# %%
validation_loader = DataLoader(validation_data,
                               batch_size= batch_size,
                                shuffle=True,
                               pin_memory=True)

model.eval()
total_e = 0.0
total_per = 0.0
counter = 0
for i, (data, _) in enumerate(validation_loader):
    num=1
    data = data.cuda()
    vq_loss, data_recon, x_recon_ae, perplexity = model(data,num)
    expectation = vq_loss[1]
    W = vq_loss[2]
    vq_loss = vq_loss[0]
    recon_error = F.mse_loss(data_recon, data)#/data_variance
    recon_error_ae = F.mse_loss(x_recon_ae, data)# / data_variance
    p = F.sigmoid(model._a1)
    total_e += recon_error/data_variance
    total_per += perplexity
    counter +=1

print("---VALIDATION---")
print("recon_error : " , total_e/counter)
print("perplexity : " , total_per/counter)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1805: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ---VALIDATION---
# recon_error :  tensor(0.0821, device='cuda:0', grad_fn=<DivBackward0>)
# perplexity :  tensor(71.0905, device='cuda:0')

# %% [markdown]
# ## Plot Loss

# %% [markdown]
# train_res_recon_error_smooth = savgol_filter(train_res_recon_error, 201, 7)
# train_res_perplexity_smooth = savgol_filter(train_res_perplexity, 201, 7)

# %%
f = plt.figure(figsize=(16,8))
ax = f.add_subplot(1,2,1)
ax.plot(train_res_recon_error_smooth)
ax.set_yscale('log')
ax.set_title('Smoothed NMSE.')
ax.set_xlabel('iteration')

ax = f.add_subplot(1,2,2)
ax.plot(train_res_perplexity_smooth)
ax.set_title('Smoothed Average codebook usage (perplexity).')
ax.set_xlabel('iteration')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2968398f0b48> in <module>()
#       1 f = plt.figure(figsize=(16,8))
#       2 ax = f.add_subplot(1,2,1)
# ----> 3 ax.plot(train_res_recon_error_smooth)
#       4 ax.set_yscale('log')
#       5 ax.set_title('Smoothed NMSE.')
#
# NameError: name 'train_res_recon_error_smooth' is not defined

# %% [markdown]
# ## View Reconstructions

# %%
validation_loader = DataLoader(validation_data,
                               batch_size= 8,
                                shuffle=True,
                               pin_memory=True)
model.eval()

(valid_originals, _) = next(iter(validation_loader))
valid_originals = valid_originals.to(device)

vq_output_eval = model._pre_vq_conv(model._encoder(valid_originals))
_, valid_quantize, _, _ = model._vq_vae(vq_output_eval,1.0)
valid_reconstructions = model._decoder(valid_quantize)

# %%
(train_originals, _) = next(iter(training_loader))
train_originals = train_originals.to(device)
_, train_reconstructions, _, _ = model._vq_vae(train_originals,1.0)

# %%
def show(img):
    npimg = img.numpy()
    fig = plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
    fig.axes.get_xaxis().set_visible(False)
    fig.axes.get_yaxis().set_visible(False)

# %%
show(make_grid(valid_reconstructions.cpu().data)+0.5, )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
show(make_grid(valid_originals.cpu()+0.5))

# %% [markdown]
# ## View Embedding

# %%
proj = umap.UMAP(n_neighbors=3,
                 min_dist=0.1,
                 metric='cosine').fit_transform(model._vq_vae._embedding.weight.data.cpu())

# %%
plt.scatter(proj[:,0], proj[:,1], alpha=0.3)
